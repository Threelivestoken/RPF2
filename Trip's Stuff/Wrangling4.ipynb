# %%
import pandas as pd
import json
#for plotting
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

#statistics
import statistics as stat

# %%
#plan
#associate genres with each playlist

# %%
with open("mpd.slice.0-999.json",'r') as json_file:
    data=json.load(json_file)

# %%
#Create library with artists and their genres
#1First stuff(load file)
with open("artists_0-999.json",'r') as json_file:
    df_2=json.load(json_file)
#2
artist_dict={"name":[],"genres":[]}
for ID in df_2:
    artist_dict["name"].append(df_2[ID]["name"])
    artist_dict["genres"].append(df_2[ID]["genres"])
#3
genre={"name":[],"genre":[]}
for ID in df_2:
    if df_2[ID]["genres"]==list:
        genre[df_2[ID]["name"]]=df_2[ID]["genres"]
    else:
        genre[df_2[ID]["name"]]=df_2[ID]["genres"]
    #make list of names in genre dict
    genre["name"].append(df_2[ID]["name"])
#function to find the genres
def getgenres(artist):
    return genre[artist]

# %%
#function to find the genres
def getplayistgenres(playlists_df,playlist):
    playlist=data["playlists"][playlist]
    
    
    
    
    
    return foundgenres

# %%
#thislist.count("apple")
playlist=0


#test stuff that will be turned into function
genrelist=[]
playlist=data["playlists"][playlist]["tracks"]

for taco in range(len(playlist)):
    #find if name in in list of genres so there is no error of no name
    if genre["name"].count(playlist[taco]["artist_name"])>0:
        currentgenres=getgenres(playlist[taco]["artist_name"]#so that there is no nested lists
        #search for lists(incomplete)
        for burrito in range(len(currentgenres)):                
            genrelist.append(getgenres(playlist[taco]["artist_name"][burrito]))
# Out:
#   File "C:\Users\ejackson11\AppData\Local\Temp\ipykernel_1644\3256035323.py", line 13
#     for burrito in range(len(currentgenres)):
#                                             ^
# SyntaxError: invalid syntax

# %%
genrelist
# Out:
# [['dance pop',
#   'hip hop',
#   'hip pop',
#   'neo soul',
#   'pop rap',
#   'r&b',
#   'rap',
#   'urban contemporary',
#   'virginia hip hop'],
#  ['dance pop', 'pop'],
#  ['pop', 'r&b'],
#  ['dance pop', 'pop'],
#  ['pop rap', 'reggae fusion'],
#  ['dance pop', 'girl group', 'pop'],
#  ['dance pop', 'girl group', 'pop', 'r&b', 'urban contemporary'],
#  ['canadian latin', 'canadian pop', 'dance pop', 'pop'],
#  ['dance pop', 'pop', 'post-teen pop'],
#  ['dance pop', 'pop', 'post-teen pop'],
#  ['dance pop', 'pop', 'post-teen pop'],
#  ['dance pop', 'hip pop', 'pop rap', 'r&b', 'urban contemporary'],
#  ['dance pop',
#   'hip pop',
#   'r&b',
#   'rap',
#   'southern hip hop',
#   'trap',
#   'urban contemporary'],
#  ['canadian pop', 'candy pop', 'dance pop', 'pop'],
#  ['r&b', 'rap'],
#  ['pop', 'r&b'],
#  ['dance pop', 'girl group', 'pop', 'r&b', 'urban contemporary'],
#  ['lilith', 'new wave pop', 'permanent wave', 'pop rock', 'singer-songwriter'],
#  ['neon pop punk', 'pop punk', 'pop rock', 'texas pop punk'],
#  ['boy band', 'neon pop punk', 'pixie'],
#  ['r&b', 'rap'],
#  ['boy band', 'pop'],
#  ['hip pop', 'trap queen'],
#  ['eurodance', 'europop', 'german techno', 'melbourne bounce international'],
#  ['dance pop', 'pop'],
#  ['dance pop', 'pop', 'r&b', 'urban contemporary'],
#  ['pop'],
#  ['dance pop', 'pop rap', 'post-teen pop'],
#  ['r&b', 'rap'],
#  ['dance pop', 'pop'],
#  ['dance pop', 'pop', 'r&b', 'urban contemporary'],
#  ['canadian pop', 'pop'],
#  ['escape room', 'indietronica', 'new rave'],
#  ['alternative rock', 'dance rock', 'modern rock', 'permanent wave', 'rock'],
#  ['alternative metal',
#   'modern rock',
#   'pop punk',
#   'punk',
#   'rock',
#   'socal pop punk'],
#  ['dance pop', 'girl group', 'pop'],
#  ['canadian pop', 'pop'],
#  ['alternative metal',
#   'modern rock',
#   'neo mellow',
#   'neon pop punk',
#   'pop punk',
#   'pop rock',
#   'post-grunge'],
#  ['canadian pop', 'pop'],
#  ['lilith', 'neo mellow', 'piano rock', 'pop rock', 'post-teen pop'],
#  [],
#  ['pop'],
#  ['dance pop', 'pop', 'post-teen pop'],
#  ['pop', 'post-teen pop'],
#  ['canadian pop', 'candy pop', 'dance pop', 'pop'],
#  ['neon pop punk', 'piano rock', 'pop punk']]

# %%
playlist
# Out:
# [{'pos': 0,
#   'artist_name': 'Survivor',
#   'track_uri': 'spotify:track:2HHtWyy5CgaQbC7XSoOb0e',
#   'artist_uri': 'spotify:artist:26bcq2nyj5GB7uRr558iQg',
#   'track_name': 'Eye of the Tiger',
#   'album_uri': 'spotify:album:4PT9VulQaQP6XR1xBI2x1W',
#   'duration_ms': 243773,
#   'album_name': 'Eye Of The Tiger'},
#  {'pos': 1,
#   'artist_name': 'Daniel Tidwell',
#   'track_uri': 'spotify:track:1MYYt7h6amcrauCOoso3Gx',
#   'artist_uri': 'spotify:artist:7zdmbPudNX4SQJXnYIuCTC',
#   'track_name': 'Libera Me From Hell (Tengen Toppa Gurren Lagann)',
#   'album_uri': 'spotify:album:3q8vR3PFV8kG1m1Iv8DpKq',
#   'duration_ms': 70294,
#   'album_name': 'Versus Hollywood'},
#  {'pos': 2,
#   'artist_name': 'Daniel Tidwell',
#   'track_uri': 'spotify:track:3x2mJ2bjCIU70NrH49CtYR',
#   'artist_uri': 'spotify:artist:7zdmbPudNX4SQJXnYIuCTC',
#   'track_name': 'Pokémon Theme',
#   'album_uri': 'spotify:album:3q8vR3PFV8kG1m1Iv8DpKq',
#   'duration_ms': 65306,
#   'album_name': 'Versus Hollywood'},
#  {'pos': 3,
#   'artist_name': 'Daniel Tidwell',
#   'track_uri': 'spotify:track:1Pm3fq1SC6lUlNVBGZi3Em',
#   'artist_uri': 'spotify:artist:7zdmbPudNX4SQJXnYIuCTC',
#   'track_name': 'Concerning Hobbits (The Lord of the Rings)',
#   'album_uri': 'spotify:album:3q8vR3PFV8kG1m1Iv8DpKq',
#   'duration_ms': 108532,
#   'album_name': 'Versus Hollywood'},
#  {'pos': 4,
#   'artist_name': 'Daniel Tidwell',
#   'track_uri': 'spotify:track:1NXTEkIeRL59NK61QuhYUl',
#   'artist_uri': 'spotify:artist:7zdmbPudNX4SQJXnYIuCTC',
#   'track_name': 'The Blood of Cuchulainn (The Boondock Saints)',
#   'album_uri': 'spotify:album:3q8vR3PFV8kG1m1Iv8DpKq',
#   'duration_ms': 214268,
#   'album_name': 'Versus Hollywood'},
#  {'pos': 5,
#   'artist_name': 'Daniel Tidwell',
#   'track_uri': 'spotify:track:3RGlJJFkWEavxeRQr9ivAd',
#   'artist_uri': 'spotify:artist:7zdmbPudNX4SQJXnYIuCTC',
#   'track_name': "He's a Pirate (Pirates of the Caribbean)",
#   'album_uri': 'spotify:album:3q8vR3PFV8kG1m1Iv8DpKq',
#   'duration_ms': 110219,
#   'album_name': 'Versus Hollywood'},
#  {'pos': 6,
#   'artist_name': 'Daniel Tidwell',
#   'track_uri': 'spotify:track:0e9hR1vTrzlUvFH5PgA9rY',
#   'artist_uri': 'spotify:artist:7zdmbPudNX4SQJXnYIuCTC',
#   'track_name': "Very Bloody Tears (Castlevania II: Simon's Quest)",
#   'album_uri': 'spotify:album:60wUpRwDRF1jmViHaW2yu4',
#   'duration_ms': 207520,
#   'album_name': 'Versus Video Games'},
#  {'pos': 7,
#   'artist_name': 'Kaleptik',
#   'track_uri': 'spotify:track:7dkbEHIMLoeuG4zXGmzhEH',
#   'artist_uri': 'spotify:artist:6BKWwLs98ZY3ifhCDNGvLk',
#   'track_name': 'U.N. Owen Was Her? (Remix)',
#   'album_uri': 'spotify:album:38tJMNu2lPatR7xnPchOOB',
#   'duration_ms': 226000,
#   'album_name': 'Video Game Remixes, Vol. 1'},
#  {'pos': 8,
#   'artist_name': 'Ben Foster',
#   'track_uri': 'spotify:track:7nZnCjIJ8JigdMqJ36yRRm',
#   'artist_uri': 'spotify:artist:6Gp8BbKAqPO3R0UAYkm8J0',
#   'track_name': 'I am the Doctor in Utah',
#   'album_uri': 'spotify:album:2t34tkX7TR5rYKMu3WYO0z',
#   'duration_ms': 104600,
#   'album_name': 'Doctor Who: Series 6 (Original Television Soundtrack)'},
#  {'pos': 9,
#   'artist_name': 'Leslie Odom Jr.',
#   'track_uri': 'spotify:track:2TK2KSrzXD6W01qjXVjNGh',
#   'artist_uri': 'spotify:artist:3cR4rhS2hBWqI7rJEBacvN',
#   'track_name': 'The Room Where It Happens',
#   'album_uri': 'spotify:album:1kCHru7uhxBUdzkm4gzRQc',
#   'duration_ms': 318214,
#   'album_name': 'Hamilton'},
#  {'pos': 10,
#   'artist_name': 'Christopher Jackson',
#   'track_uri': 'spotify:track:3nJYcY9yvKP8Oi2Ml8brXt',
#   'artist_uri': 'spotify:artist:6sLwRSXSUF5JTUnQaFenyj',
#   'track_name': 'Right Hand Man',
#   'album_uri': 'spotify:album:1kCHru7uhxBUdzkm4gzRQc',
#   'duration_ms': 321696,
#   'album_name': 'Hamilton'},
#  {'pos': 11,
#   'artist_name': 'Leslie Odom Jr.',
#   'track_uri': 'spotify:track:4TTV7EcfroSLWzXRY6gLv6',
#   'artist_uri': 'spotify:artist:3cR4rhS2hBWqI7rJEBacvN',
#   'track_name': 'Alexander Hamilton',
#   'album_uri': 'spotify:album:1kCHru7uhxBUdzkm4gzRQc',
#   'duration_ms': 236737,
#   'album_name': 'Hamilton'},
#  {'pos': 12,
#   'artist_name': 'Lin-Manuel Miranda',
#   'track_uri': 'spotify:track:4cxvludVmQxryrnx1m9FqL',
#   'artist_uri': 'spotify:artist:4aXXDj9aZnlshx7mzj3W1N',
#   'track_name': 'My Shot',
#   'album_uri': 'spotify:album:1kCHru7uhxBUdzkm4gzRQc',
#   'duration_ms': 333154,
#   'album_name': 'Hamilton'},
#  {'pos': 13,
#   'artist_name': 'Led Zeppelin',
#   'track_uri': 'spotify:track:5CQ30WqJwcep0pYcV4AMNc',
#   'artist_uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp',
#   'track_name': 'Stairway To Heaven',
#   'album_uri': 'spotify:album:44Ig8dzqOkvkGDzaUof9lK',
#   'duration_ms': 482830,
#   'album_name': 'Led Zeppelin IV'},
#  {'pos': 14,
#   'artist_name': 'Collective Soul',
#   'track_uri': 'spotify:track:1HZ3cUZUw5htSFmah1V8Ko',
#   'artist_uri': 'spotify:artist:4e5V1Q2dKCzbLVMQ8qbTn6',
#   'track_name': 'Shine',
#   'album_uri': 'spotify:album:3uSVy9q97sAzd5UE0dMdOT',
#   'duration_ms': 306040,
#   'album_name': 'Hints, Allegations & Things Left Unsaid'},
#  {'pos': 15,
#   'artist_name': 'Nightwish',
#   'track_uri': 'spotify:track:43pmQcgxMMhJu1gPW2ZdNz',
#   'artist_uri': 'spotify:artist:2NPduAUeLVsfIauhRwuft1',
#   'track_name': 'Ghost Love Score',
#   'album_uri': 'spotify:album:7pYmXPG9Wj5nvC5jFM0yEW',
#   'duration_ms': 602080,
#   'album_name': 'Once'},
#  {'pos': 16,
#   'artist_name': 'Seal',
#   'track_uri': 'spotify:track:6Vz7vzOpCwKeSQlfViibuY',
#   'artist_uri': 'spotify:artist:5GtMEZEeFFsuHY8ad4kOxv',
#   'track_name': 'Crazy',
#   'album_uri': 'spotify:album:3NehJpD5x3MUtpl8jDTHaa',
#   'duration_ms': 356520,
#   'album_name': 'Best 1991 - 2004'},
#  {'pos': 17,
#   'artist_name': 'The Rolling Stones',
#   'track_uri': 'spotify:track:4sFbojhVXQv7dBC9PVCcRn',
#   'artist_uri': 'spotify:artist:22bE4uQ6baNwSHPVcDxLCe',
#   'track_name': 'Sympathy For The Devil',
#   'album_uri': 'spotify:album:5WZFtmADuJUZPtt0NER0Qi',
#   'duration_ms': 377746,
#   'album_name': 'Beggars Banquet'},
#  {'pos': 18,
#   'artist_name': 'The Rolling Stones',
#   'track_uri': 'spotify:track:1dv3ePjze9tPq2pk8eWJdR',
#   'artist_uri': 'spotify:artist:22bE4uQ6baNwSHPVcDxLCe',
#   'track_name': 'Gimme Shelter',
#   'album_uri': 'spotify:album:0c78nsgqX6VfniSNWIxwoD',
#   'duration_ms': 270773,
#   'album_name': 'Let It Bleed'},
#  {'pos': 19,
#   'artist_name': 'Lynyrd Skynyrd',
#   'track_uri': 'spotify:track:5EWPGh7jbTNO2wakv8LjUI',
#   'artist_uri': 'spotify:artist:4MVyzYMgTwdP7Z49wAZHx0',
#   'track_name': 'Free Bird',
#   'album_uri': 'spotify:album:6DExt1eX4lflLacVjHHbOs',
#   'duration_ms': 547106,
#   'album_name': "Pronounced' Leh-'Nerd 'Skin-'Nerd"},
#  {'pos': 20,
#   'artist_name': 'Boston',
#   'track_uri': 'spotify:track:1GqlvSEtMx5xbGptxOTTyk',
#   'artist_uri': 'spotify:artist:29kkCKKGXheHuoO829FxWK',
#   'track_name': 'Peace of Mind',
#   'album_uri': 'spotify:album:2QLp07RO6anZHmtcKTEvSC',
#   'duration_ms': 303586,
#   'album_name': 'Boston'},
#  {'pos': 21,
#   'artist_name': 'Boston',
#   'track_uri': 'spotify:track:39C5FuZ8C8M0QI8CrMsPkR',
#   'artist_uri': 'spotify:artist:29kkCKKGXheHuoO829FxWK',
#   'track_name': 'Foreplay / Long Time',
#   'album_uri': 'spotify:album:2QLp07RO6anZHmtcKTEvSC',
#   'duration_ms': 467640,
#   'album_name': 'Boston'},
#  {'pos': 22,
#   'artist_name': 'Toto',
#   'track_uri': 'spotify:track:4aVuWgvD0X63hcOCnZtNFA',
#   'artist_uri': 'spotify:artist:0PFtn5NtBbbUNbU9EAmIWF',
#   'track_name': 'Hold the Line',
#   'album_uri': 'spotify:album:1mnu4hYvdwQgZXcNvtJ3D3',
#   'duration_ms': 235800,
#   'album_name': 'Toto'},
#  {'pos': 23,
#   'artist_name': 'Kansas',
#   'track_uri': 'spotify:track:4DMKwE2E2iYDKY01C335Uw',
#   'artist_uri': 'spotify:artist:2hl0xAkS2AIRAu23TVMBG1',
#   'track_name': 'Carry on Wayward Son',
#   'album_uri': 'spotify:album:7MejfRSNnrpcLZIxkeZDqR',
#   'duration_ms': 323000,
#   'album_name': 'Leftoverture'},
#  {'pos': 24,
#   'artist_name': 'Queen',
#   'track_uri': 'spotify:track:1AhDOtG9vPSOmsWgNW0BEY',
#   'artist_uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d',
#   'track_name': 'Bohemian Rhapsody - Remastered 2011',
#   'album_uri': 'spotify:album:1TSZDcvlPtAnekTaItI3qO',
#   'duration_ms': 354320,
#   'album_name': 'A Night At The Opera'},
#  {'pos': 25,
#   'artist_name': 'Lynyrd Skynyrd',
#   'track_uri': 'spotify:track:4CJVkjo5WpmUAKp3R44LNb',
#   'artist_uri': 'spotify:artist:4MVyzYMgTwdP7Z49wAZHx0',
#   'track_name': 'Sweet Home Alabama',
#   'album_uri': 'spotify:album:5rtOJsiDDjA9V5306cyTRS',
#   'duration_ms': 281147,
#   'album_name': 'Second Helping'},
#  {'pos': 26,
#   'artist_name': 'Boston',
#   'track_uri': 'spotify:track:1QEEqeFIZktqIpPI4jSVSF',
#   'artist_uri': 'spotify:artist:29kkCKKGXheHuoO829FxWK',
#   'track_name': 'More Than a Feeling',
#   'album_uri': 'spotify:album:2QLp07RO6anZHmtcKTEvSC',
#   'duration_ms': 285133,
#   'album_name': 'Boston'},
#  {'pos': 27,
#   'artist_name': 'Led Zeppelin',
#   'track_uri': 'spotify:track:2nVHqZbOGkKWzlcy1aMbE7',
#   'artist_uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp',
#   'track_name': 'Kashmir',
#   'album_uri': 'spotify:album:1lZahjeu4AhPkg9JARZr5F',
#   'duration_ms': 508200,
#   'album_name': 'Physical Graffiti'},
#  {'pos': 28,
#   'artist_name': 'Ben Foster',
#   'track_uri': 'spotify:track:6MpMuAuLzFFfwB8QzWL1iZ',
#   'artist_uri': 'spotify:artist:6Gp8BbKAqPO3R0UAYkm8J0',
#   'track_name': 'The Majestic Tale (Of A Madman In A Box)',
#   'album_uri': 'spotify:album:2t34tkX7TR5rYKMu3WYO0z',
#   'duration_ms': 241160,
#   'album_name': 'Doctor Who: Series 6 (Original Television Soundtrack)'},
#  {'pos': 29,
#   'artist_name': "Guns N' Roses",
#   'track_uri': 'spotify:track:7o2CTH4ctstm8TNelqjb51',
#   'artist_uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC',
#   'track_name': "Sweet Child O' Mine",
#   'album_uri': 'spotify:album:3I9Z1nDCL4E0cP62flcbI5',
#   'duration_ms': 356080,
#   'album_name': 'Appetite For Destruction'},
#  {'pos': 30,
#   'artist_name': 'Creedence Clearwater Revival',
#   'track_uri': 'spotify:track:4BP3uh0hFLFRb5cjsgLqDh',
#   'artist_uri': 'spotify:artist:3IYUhFvPQItj6xySrBmZkd',
#   'track_name': 'Fortunate Son',
#   'album_uri': 'spotify:album:31q47gQszFt0CddSyMksgO',
#   'duration_ms': 140773,
#   'album_name': 'Willy And The Poor Boys'},
#  {'pos': 31,
#   'artist_name': 'Scorpions',
#   'track_uri': 'spotify:track:0XIvZ82aDF7JiSi3ZE320u',
#   'artist_uri': 'spotify:artist:27T030eWyCQRmDyuvr1kxY',
#   'track_name': 'Rock You Like A Hurricane',
#   'album_uri': 'spotify:album:6d4dgGamepehj0WwsYXTKi',
#   'duration_ms': 252493,
#   'album_name': 'Love At First Sting'},
#  {'pos': 32,
#   'artist_name': 'Rush',
#   'track_uri': 'spotify:track:3QZ7uX97s82HFYSmQUAN1D',
#   'artist_uri': 'spotify:artist:2Hkut4rAAyrQxRdof7FVJq',
#   'track_name': 'Tom Sawyer',
#   'album_uri': 'spotify:album:2xg7iIKoSqaDNpDbJnyCjY',
#   'duration_ms': 276880,
#   'album_name': 'Moving Pictures'},
#  {'pos': 33,
#   'artist_name': 'Rush',
#   'track_uri': 'spotify:track:6UGHk2cmbDC1oidVjXcCKo',
#   'artist_uri': 'spotify:artist:2Hkut4rAAyrQxRdof7FVJq',
#   'track_name': 'Red Barchetta',
#   'album_uri': 'spotify:album:2xg7iIKoSqaDNpDbJnyCjY',
#   'duration_ms': 370426,
#   'album_name': 'Moving Pictures'},
#  {'pos': 34,
#   'artist_name': 'Rush',
#   'track_uri': 'spotify:track:3lpDrxUkr0tIe1kmJvdK7d',
#   'artist_uri': 'spotify:artist:2Hkut4rAAyrQxRdof7FVJq',
#   'track_name': 'YYZ',
#   'album_uri': 'spotify:album:2xg7iIKoSqaDNpDbJnyCjY',
#   'duration_ms': 265840,
#   'album_name': 'Moving Pictures'},
#  {'pos': 35,
#   'artist_name': 'Rush',
#   'track_uri': 'spotify:track:0K6yUnIKNsFtfIpTgGtcHm',
#   'artist_uri': 'spotify:artist:2Hkut4rAAyrQxRdof7FVJq',
#   'track_name': 'Limelight',
#   'album_uri': 'spotify:album:2xg7iIKoSqaDNpDbJnyCjY',
#   'duration_ms': 259839,
#   'album_name': 'Moving Pictures'},
#  {'pos': 36,
#   'artist_name': 'Rush',
#   'track_uri': 'spotify:track:0hBby0yygBY1u3m6tSpZgC',
#   'artist_uri': 'spotify:artist:2Hkut4rAAyrQxRdof7FVJq',
#   'track_name': 'The Camera Eye',
#   'album_uri': 'spotify:album:2xg7iIKoSqaDNpDbJnyCjY',
#   'duration_ms': 658986,
#   'album_name': 'Moving Pictures'},
#  {'pos': 37,
#   'artist_name': 'Rush',
#   'track_uri': 'spotify:track:6cbBAD1AAYVaQR1cx89AZX',
#   'artist_uri': 'spotify:artist:2Hkut4rAAyrQxRdof7FVJq',
#   'track_name': 'Witch Hunt',
#   'album_uri': 'spotify:album:2xg7iIKoSqaDNpDbJnyCjY',
#   'duration_ms': 285533,
#   'album_name': 'Moving Pictures'},
#  {'pos': 38,
#   'artist_name': 'Rush',
#   'track_uri': 'spotify:track:1k0GxoZYv3Yx5mNeXMOZN2',
#   'artist_uri': 'spotify:artist:2Hkut4rAAyrQxRdof7FVJq',
#   'track_name': 'Vital Signs',
#   'album_uri': 'spotify:album:2xg7iIKoSqaDNpDbJnyCjY',
#   'duration_ms': 286226,
#   'album_name': 'Moving Pictures'}]

# %%
data["playlists"][1]
playcorrect={}
for playlist in range(len(data["playlists"])):
    #playcorrect[playlist], create temporary library so that I can put some data in it
    lib={"artist":[],"genre":[]}
    for songinplaylist in range(len(data["playlists"][playlist]["tracks"])):
        #Artist name:data["playlists"][playlist]["tracks"][songinplaylist]["artist_name"]
        name=data["playlists"][playlist]["tracks"][songinplaylist]["artist_name"]#get the artist's name so that you can get the genres and put them in
        #check if the name is in the list, and if so you add to the list of genres, either way you add the name to the artistlist:
        if name in genre:
            lib["genre"].append(genre[name])
        lib["artist"].append(name)
    #find the most likely top genres
    unique=lib["genre"].unique()
    
#print(artistslist)
#print(artistslist)
        #artistlist.append(data["playlists"][playlist]["tracks"][songinplaylist]["artist_name"])

# %%
data["playlists"][0]["tracks"][0]["artist_name"]

# %%
with open("songs_0-999.json",'r') as json_file:
    jsongs=json.load(json_file)

# %%
#for taco in jsongs:
#    print(taco)
#jsongs["0UaMYEvWZi0ZqiDOoHU3YI"]

# %%
x=[]
#df_playlist=pd.DataFrame(data)
#you get a list of all of the artists(x) in order
for playlist in range(len(data["playlists"])):
    for song in range(len(data["playlists"][playlist]["tracks"])):
        x.append(data["playlists"][playlist]["tracks"][song]["artist_name"])
#jsongs["0UaMYEvWZi0ZqiDOoHU3YI"]

# %%
#data["playlists"][0]["tracks"][0]["artist_name"]

# %%
#Not official stuff, just for looking
y=[]
for taco in range(len(data["playlists"])):
    y.append(len(data["playlists"][taco]["tracks"]))
df=pd.DataFrame({"x":range(1,len(y)+1),"y":sorted(y)})#sorted(y)

sns.lineplot(data=df,x='x',y='y')
plt.xlabel("x")
plt.ylabel("y")
stat.mean(y)
print(min(y))

# %%
#len(data["playlists"][taco]["tracks"])

# %%
#make variable called artist so that you can then make a dataframe that has songs and the genre
#for taco in range(len(data["playlists"])):
#    for burrito in range(len(data["playlists"][taco]["tracks"])):
#        artist=data["playlists"][taco]["tracks"][burrito]["artist_name"]

# %%
#x=data["playlists"][0]["tracks"]
#x
#for hotdog in range(len(x)):
#    data["playlists"][0]["tracks"][hotdog]["artist_name"]
#
#[0]["artist_name"]

# %%
#example library
library={
    "playlist1":[["Song","Artist",["Pop","rock"]],["Song","Artist",["Pop","rock"]]] 
}

# %%
data_art

# %%
pip show pandas
