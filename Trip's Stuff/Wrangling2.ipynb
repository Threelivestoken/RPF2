# %%
import pandas as pd
import json
#for plotting
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

#statistics
import statistics as stat

# %%
with open("mpd.slice.0-999.json",'r') as json_file:
    data=json.load(json_file)

# %%
#Create library with artists and their genres
#1First stuff(load file)
with open("artists_0-999.json",'r') as json_file:
    df_2=json.load(json_file)
#2
artist_dict={"name":[],"genres":[]}
for ID in df_2:
    artist_dict["name"].append(df_2[ID]["name"])
    artist_dict["genres"].append(df_2[ID]["genres"])
#3
data_art={}
for ID in df_2:
    if df_2[ID]["genres"]==list:
        data_art[df_2[ID]["name"]]=df_2[ID]["genres"]
    else:
        data_art[df_2[ID]["name"]]=[df_2[ID]["genres"]]

# %%
with open("songs_0-999.json",'r') as json_file:
    jsongs=json.load(json_file)

# %%
#for taco in jsongs:
#    print(taco)
#jsongs["0UaMYEvWZi0ZqiDOoHU3YI"]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wIVse2owClT7go1WT98tk'},
#     'href': 'https://api.spotify.com/v1/artists/2wIVse2owClT7go1WT98tk',
#     'id': '2wIVse2owClT7go1WT98tk',
#     'name': 'Missy Elliott',
#     'type': 'artist',
#     'uri': 'spotify:artist:2wIVse2owClT7go1WT98tk'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6vV5UrXcfyQD1wu4Qo2I9K'},
#   'href': 'https://api.spotify.com/v1/albums/6vV5UrXcfyQD1wu4Qo2I9K',
#   'id': '6vV5UrXcfyQD1wu4Qo2I9K',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f1dfae21eaac0d24fb3dcf5a',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f1dfae21eaac0d24fb3dcf5a',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f1dfae21eaac0d24fb3dcf5a',
#     'width': 64}],
#   'name': 'The Cookbook',
#   'release_date': '2005-07-04',
#   'release_date_precision': 'day',
#   'total_tracks': 16,
#   'type': 'album',
#   'uri': 'spotify:album:6vV5UrXcfyQD1wu4Qo2I9K'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wIVse2owClT7go1WT98tk'},
#    'href': 'https://api.spotify.com/v1/artists/2wIVse2owClT7go1WT98tk',
#    'id': '2wIVse2owClT7go1WT98tk',
#    'name': 'Missy Elliott',
#    'type': 'artist',
#    'uri': 'spotify:artist:2wIVse2owClT7go1WT98tk'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2NdeV5rLm47xAvogXrYhJX'},
#    'href': 'https://api.spotify.com/v1/artists/2NdeV5rLm47xAvogXrYhJX',
#    'id': '2NdeV5rLm47xAvogXrYhJX',
#    'name': 'Ciara',
#    'type': 'artist',
#    'uri': 'spotify:artist:2NdeV5rLm47xAvogXrYhJX'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/15GGbJKqC6w0VYyAJtjej6'},
#    'href': 'https://api.spotify.com/v1/artists/15GGbJKqC6w0VYyAJtjej6',
#    'id': '15GGbJKqC6w0VYyAJtjej6',
#    'name': 'Fatman Scoop',
#    'type': 'artist',
#    'uri': 'spotify:artist:15GGbJKqC6w0VYyAJtjej6'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 226863,
#  'explicit': True,
#  'external_ids': {'isrc': 'USEE10414022'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/0UaMYEvWZi0ZqiDOoHU3YI'},
#  'href': 'https://api.spotify.com/v1/tracks/0UaMYEvWZi0ZqiDOoHU3YI',
#  'id': '0UaMYEvWZi0ZqiDOoHU3YI',
#  'is_local': False,
#  'name': 'Lose Control (feat. Ciara & Fat Man Scoop)',
#  'popularity': 69,
#  'preview_url': 'https://p.scdn.co/mp3-preview/253a76c453026570394aa26156691d1d81b387c0?cid=0bf1651cdb2749dc91e2bbc57c32b90e',
#  'track_number': 4,
#  'type': 'track',
#  'uri': 'spotify:track:0UaMYEvWZi0ZqiDOoHU3YI'}

# %%
x=0
for taco in data["playlists"][1]:
    if x<50:
        print(taco)
    x+=1
    
#jsongs["0UaMYEvWZi0ZqiDOoHU3YI"]
# Out:
# name
# collaborative
# pid
# modified_at
# num_tracks
# num_albums
# num_followers
# tracks
# num_edits
# duration_ms
# num_artists

# %%
#data["playlists"][0]["tracks"][0]["artist_name"]

# %%
#make list of songs and their genres

# %%
#Not official stuff, just for looking
y=[]
for taco in range(len(data["playlists"])):
    y.append(len(data["playlists"][taco]["tracks"]))
df=pd.DataFrame({"x":range(1,len(y)+1),"y":sorted(y)})#sorted(y)

sns.lineplot(data=df,x='x',y='y')
plt.xlabel("x")
plt.ylabel("y")
stat.mean(y)
# Out:
# 67.503

# %%
#len(data["playlists"][taco]["tracks"])

# %%
#make variable called artist so that you can then make a dataframe that has songs and the genre
#for taco in range(len(data["playlists"])):
#    for burrito in range(len(data["playlists"][taco]["tracks"])):
#        artist=data["playlists"][taco]["tracks"][burrito]["artist_name"]

# %%
#x=data["playlists"][0]["tracks"]
#x
#for hotdog in range(len(x)):
#    data["playlists"][0]["tracks"][hotdog]["artist_name"]
#
#[0]["artist_name"]

# %%
data_art
# Out:
# {'Missy Elliott': [['dance pop',
#    'hip hop',
#    'hip pop',
#    'neo soul',
#    'pop rap',
#    'r&b',
#    'rap',
#    'urban contemporary',
#    'virginia hip hop']],
#  'Britney Spears': [['dance pop', 'pop']],
#  'Beyoncé': [['pop', 'r&b']],
#  'Justin Timberlake': [['dance pop', 'pop']],
#  'Shaggy': [['pop rap', 'reggae fusion']],
#  'USHER': [['atl hip hop',
#    'contemporary r&b',
#    'dance pop',
#    'pop',
#    'r&b',
#    'rap',
#    'south carolina hip hop',
#    'urban contemporary']],
#  'The Pussycat Dolls': [['dance pop', 'girl group', 'pop']],
#  "Destiny's Child": [['dance pop',
#    'girl group',
#    'pop',
#    'r&b',
#    'urban contemporary']],
#  'Outkast': [['atl hip hop',
#    'dirty south rap',
#    'hip hop',
#    'old school atlanta hip hop',
#    'rap',
#    'southern hip hop']],
#  'Nelly Furtado': [['canadian latin', 'canadian pop', 'dance pop', 'pop']],
#  'Jesse McCartney': [['dance pop', 'pop', 'post-teen pop']],
#  'Cassie': [['dance pop', 'hip pop', 'pop rap', 'r&b', 'urban contemporary']],
#  'Omarion': [['dance pop',
#    'hip pop',
#    'r&b',
#    'rap',
#    'southern hip hop',
#    'trap',
#    'urban contemporary']],
#  'Avril Lavigne': [['canadian pop', 'candy pop', 'dance pop', 'pop']],
#  'Chris Brown': [['r&b', 'rap']],
#  'Sheryl Crow': [['lilith',
#    'new wave pop',
#    'permanent wave',
#    'pop rock',
#    'singer-songwriter']],
#  'Black Eyed Peas': [['dance pop', 'pop', 'pop rap']],
#  'Bowling For Soup': [['neon pop punk',
#    'pop punk',
#    'pop rock',
#    'texas pop punk']],
#  'The Click Five': [['boy band', 'neon pop punk', 'pixie']],
#  'Jonas Brothers': [['boy band', 'pop']],
#  'Lil Mama': [['hip pop', 'trap queen']],
#  'Cascada': [['eurodance',
#    'europop',
#    'german techno',
#    'melbourne bounce international']],
#  'Jason Derulo': [['dance pop', 'pop']],
#  'Ne-Yo': [['dance pop', 'pop', 'r&b', 'urban contemporary']],
#  'Miley Cyrus': [['pop']],
#  'BOYS LIKE GIRLS': [['neon pop punk', 'pop punk']],
#  'Iyaz': [['dance pop', 'pop rap', 'post-teen pop']],
#  'Kesha': [['dance pop', 'pop']],
#  'Justin Bieber': [['canadian pop', 'pop']],
#  'M.I.A.': [['escape room', 'indietronica', 'new rave']],
#  'The Killers': [['alternative rock',
#    'dance rock',
#    'modern rock',
#    'permanent wave',
#    'rock']],
#  'blink-182': [['alternative metal',
#    'modern rock',
#    'pop punk',
#    'punk',
#    'rock',
#    'socal pop punk']],
#  'The All-American Rejects': [['alternative metal',
#    'modern rock',
#    'neo mellow',
#    'neon pop punk',
#    'pop punk',
#    'pop rock',
#    'post-grunge']],
#  'Vanessa Carlton': [['lilith',
#    'neo mellow',
#    'piano rock',
#    'pop rock',
#    'post-teen pop']],
#  'Cris Cab': [[]],
#  'Demi Lovato': [['pop', 'post-teen pop']],
#  'We The Kings': [['neon pop punk', 'piano rock', 'pop punk']],
#  'Survivor': [['album rock', 'glam metal', 'hard rock', 'soft rock']],
#  'Daniel Tidwell': [['scorecore']],
#  'Kaleptik': [[]],
#  'Ben Foster': [['british soundtrack']],
#  'Leslie Odom Jr.': [['broadway', 'show tunes', 'vocal jazz']],
#  'Christopher Jackson': [['show tunes']],
#  'Lin-Manuel Miranda': [['broadway', 'show tunes']],
#  'Led Zeppelin': [['album rock', 'classic rock', 'hard rock', 'rock']],
#  'Collective Soul': [['alternative rock',
#    'grunge',
#    'nu metal',
#    'pop rock',
#    'post-grunge',
#    'rock']],
#  'Nightwish': [['fantasy metal',
#    'finnish metal',
#    'finnish power metal',
#    'gothic metal',
#    'gothic symphonic metal',
#    'opera metal',
#    'power metal',
#    'symphonic metal']],
#  'Seal': [['british soul', 'new wave pop']],
#  'The Rolling Stones': [['album rock',
#    'british invasion',
#    'classic rock',
#    'rock']],
#  'Lynyrd Skynyrd': [['album rock',
#    'classic rock',
#    'hard rock',
#    'rock',
#    'southern rock']],
#  'Boston': [['album rock',
#    'classic rock',
#    'glam metal',
#    'hard rock',
#    'mellow gold',
#    'rock',
#    'soft rock']],
#  'TOTO': [['album rock',
#    'classic rock',
#    'hard rock',
#    'mellow gold',
#    'rock',
#    'soft rock',
#    'yacht rock']],
#  'Kansas': [['album rock',
#    'classic rock',
#    'hard rock',
#    'heartland rock',
#    'mellow gold',
#    'progressive rock',
#    'rock',
#    'soft rock']],
#  'Queen': [['classic rock', 'glam rock', 'rock']],
#  "Guns N' Roses": [['glam metal', 'hard rock', 'rock']],
#  'Creedence Clearwater Revival': [['album rock',
#    'classic rock',
#    'country rock',
#    'rock',
#    'southern rock',
#    'swamp rock']],
#  'Scorpions': [['album rock',
#    'german hard rock',
#    'german metal',
#    'german rock',
#    'hard rock',
#    'rock']],
#  'Rush': [['album rock',
#    'canadian metal',
#    'classic canadian rock',
#    'classic rock',
#    'hard rock',
#    'progressive rock',
#    'rock']],
#  'Hoody': [['korean r&b']],
#  'Loco': [['k-pop', 'k-rap', 'korean r&b']],
#  'Park Kyung': [['korean pop']],
#  'BTS': [['k-pop', 'k-pop boy group', 'pop']],
#  'Lovelyz': [['k-pop', 'k-pop girl group']],
#  'LeeHi': [['k-pop']],
#  'AILEE': [['k-pop']],
#  'Miso': [['k-pop']],
#  'Zion.T': [['k-pop', 'k-rap', 'korean r&b']],
#  'KARD': [['k-pop']],
#  'Artist Page Redirect Cleanup 2023': [[]],
#  'Jay Park': [['k-pop', 'k-rap', 'korean r&b']],
#  'ZICO': [['k-pop', 'korean r&b']],
#  'BLACKPINK': [['k-pop', 'k-pop girl group', 'pop']],
#  'Eddy Kim': [['k-pop', 'korean pop', 'korean singer-songwriter']],
#  'Jung Yong Hwa': [['korean pop']],
#  'CNBLUE': [['k-pop', 'k-pop boy group']],
#  'Apink': [['k-pop', 'k-pop girl group']],
#  'Suzy': [['k-pop']],
#  'BAEKHYUN': [['k-pop']],
#  'V': [['j-division', 'korean ost']],
#  'BIGBANG': [['k-pop', 'k-pop boy group']],
#  'G-DRAGON': [['k-pop', 'k-rap']],
#  'TAEYANG': [['k-pop', 'korean r&b']],
#  'AKMU': [['k-pop']],
#  'EXO': [['k-pop', 'k-pop boy group']],
#  'HyunA': [['k-pop']],
#  'Jenyer': [[]],
#  'YEZI': [['k-pop']],
#  'SHIN JIMIN': [['k-pop']],
#  'Camille Saint-Saëns': [['classical',
#    'french romanticism',
#    'late romantic era']],
#  'No Vacation': [['indie garage rock', 'indie pop', 'indie surf']],
#  'Banes World': [['bedroom pop']],
#  'PWR BTTM': [['queercore']],
#  'Tears For Fears': [['new romantic',
#    'new wave',
#    'new wave pop',
#    'permanent wave',
#    'rock',
#    'sophisti-pop',
#    'synthpop']],
#  'Natureboy': [[]],
#  'Joy Again': [['pov: indie']],
#  'Part Time': [['hypnagogic pop', 'indie garage rock']],
#  'King Krule': [['uk alternative pop']],
#  'The Preatures': [['australian indie', 'australian indie rock']],
#  'DIIV': [['brooklyn indie',
#    'dream pop',
#    'dreamo',
#    'indie rock',
#    'indie surf',
#    'modern dream pop',
#    'neo-psychedelic',
#    'nu gaze',
#    'shoegaze']],
#  'Gazebos': [[]],
#  'Tacocat': [['bubblegrunge',
#    'indie punk',
#    'indie surf',
#    'power-pop punk',
#    'riot grrrl',
#    'seattle indie']],
#  'Army Navy': [['modern power pop']],
#  'The Lonely Forest': [['washington indie']],
#  'Rooney': [['modern power pop']],
#  'Bloc Party': [['alternative dance',
#    'alternative rock',
#    'dance-punk',
#    'indie rock',
#    'indietronica',
#    'modern rock',
#    'neo-synthpop',
#    'new rave']],
#  'Waxahatchee': [['alabama indie',
#    'bubblegrunge',
#    'chamber pop',
#    'countrygaze',
#    'indie pop',
#    'indie rock']],
#  'Grizzly Bear': [['art pop',
#    'baroque pop',
#    'brooklyn indie',
#    'indie rock',
#    'neo-synthpop',
#    'new weird america']],
#  'Vampire Weekend': [['baroque pop',
#    'chamber pop',
#    'garage rock',
#    'indie rock',
#    'indietronica',
#    'modern rock']],
#  'The Babies': [['garage pop', 'indie garage rock', 'noise pop']],
#  'Kopecky': [['nashville indie']],
#  'Nothing But Thieves': [['alternative pop rock',
#    'modern alternative rock',
#    'modern rock']],
#  'Dr. Dog': [['chamber pop',
#    'indie rock',
#    'modern folk rock',
#    'philly indie',
#    'pov: indie',
#    'seattle indie',
#    'stomp and holler']],
#  'My Morning Jacket': [['chamber pop',
#    'indie rock',
#    'jam band',
#    'louisville indie',
#    'melancholia',
#    'roots rock',
#    'stomp and holler']],
#  'Wet': [['brooklyn indie',
#    'electropop',
#    'indie poptimism',
#    'nyc pop',
#    'shimmer pop']],
#  'Steve Lacy': [['afrofuturism']],
#  'BROCKHAMPTON': [['boy band', 'rap']],
#  'A.Dd+': [[]],
#  'Antwon': [['underground hip hop']],
#  'Night Lovell': [['aesthetic rap',
#    'canadian hip hop',
#    'canadian trap',
#    'cloud rap',
#    'dark trap',
#    'ottawa rap']],
#  'bo en': [['experimental pop', 'pov: indie']],
#  'Cigarettes After Sex': [['ambient pop',
#    'dream pop',
#    'el paso indie',
#    'shoegaze']],
#  'dandelion hands': [['lo-fi emo', 'lo-fi indie', 'pov: indie']],
#  'Sports': [['tulsa indie']],
#  'The Kooks': [['brighton indie', 'garage rock', 'modern rock', 'rock']],
#  'Xiu Xiu': [['art pop',
#    'bay area indie',
#    'dream pop',
#    'experimental',
#    'experimental pop',
#    'experimental rock',
#    'grave wave',
#    'lo-fi',
#    'noise pop']],
#  'Moose': [['shoegaze']],
#  'Rogue Wave': [['bay area indie',
#    'chamber pop',
#    'indie rock',
#    'noise pop',
#    'oakland indie',
#    'stomp and holler']],
#  'Weezer': [['alternative rock',
#    'modern power pop',
#    'modern rock',
#    'permanent wave',
#    'rock']],
#  'Meltycanon': [['lo-fi rap']],
#  'Chairlift': [['brooklyn indie',
#    'indietronica',
#    'metropopolis',
#    'neo-synthpop']],
#  'Connan Mockasin': [['experimental pop', 'kiwi rock', 'neo-psychedelic']],
#  'Marcy Playground': [['alternative rock',
#    'grunge',
#    'pop rock',
#    'post-grunge']],
#  'Concorde': [['rock independant francais']],
#  'Mariah Carey': [['dance pop', 'pop', 'urban contemporary']],
#  'Parks, Squares and Alleys': [['modern dream pop', 'russian shoegaze']],
#  'Ween': [['alternative rock']],
#  'SWV': [['contemporary r&b',
#    'girl group',
#    'hip pop',
#    'new jack swing',
#    'r&b',
#    'urban contemporary']],
#  'Fazerdaze': [['dreamo', 'nz indie']],
#  'Mons Vi': [['bedroom pop']],
#  'Oingo Boingo': [['dance rock', 'new romantic', 'new wave', 'zolo']],
#  'salvia palth': [['countrygaze',
#    'lo-fi emo',
#    'lo-fi indie',
#    'pov: indie',
#    'slowcore',
#    'small room']],
#  'Blonde Tongues': [['modern dream pop']],
#  'Sufjan Stevens': [['art pop',
#    'baroque pop',
#    'chamber pop',
#    'indie pop',
#    'indie rock',
#    'singer-songwriter']],
#  'How To Dress Well': [['art pop', 'chillwave', 'metropopolis']],
#  'Bobby Caldwell': [['yacht rock']],
#  'Hüsker Dü': [['alternative rock',
#    'experimental rock',
#    'hardcore punk',
#    'noise pop',
#    'noise rock',
#    'post-hardcore',
#    'post-punk',
#    'power pop',
#    'punk']],
#  'The Vapors': [['mod revival', 'new wave']],
#  'Lets Kill Janice': [[]],
#  'Bedroom': [['small room']],
#  'The Truth': [[]],
#  'Gift': [[]],
#  'Floh de Cologne': [['krautrock']],
#  'May Blitz': [['psychedelic blues-rock']],
#  'Jehst': [['conscious hip hop', 'uk alternative hip hop', 'uk hip hop']],
#  'Black Moon': [['east coast hip hop', 'hardcore hip hop']],
#  'Lords Of The Underground': [['conscious hip hop',
#    'east coast hip hop',
#    'new jersey rap']],
#  'Rod McKuen': [[]],
#  'John SaFranko': [[]],
#  'WHY?': [['abstract hip hop', 'bay area indie']],
#  'Varsity': [['chicago indie', 'indie garage rock', 'indie rock']],
#  'Declan McKenna': [['pov: indie']],
#  'Phony Ppl': [['alternative r&b', 'indie soul']],
#  'Michael Kiwanuka': [['british soul',
#    'neo soul',
#    'psychedelic soul',
#    'soul']],
#  'Etta James': [['jazz blues',
#    'soul',
#    'soul blues',
#    'torch song',
#    'vocal jazz']],
#  'Jawbreaker': [['emo',
#    'emo punk',
#    'indie punk',
#    'orgcore',
#    'post-hardcore',
#    'punk']],
#  'Naked Raygun': [['chicago hardcore', 'chicago punk']],
#  'Fog Lake': [['lo-fi indie', 'newfoundland indie', 'small room']],
#  'Vansire': [['bedroom pop', 'rochester mn indie']],
#  'Good Good Blood': [[]],
#  'Ourselves the Elves': [['pinoy indie', 'pinoy rock']],
#  'Odina': [['ambient folk']],
#  'Boyscott': [['chill dream pop', 'indie garage rock']],
#  'Suburban Lawns': [['experimental rock', 'no wave', 'post-punk']],
#  'Mild High Club': [['indie garage rock', 'neo-psychedelic']],
#  'The Smashing Pumpkins': [['alternative metal',
#    'alternative rock',
#    'grunge',
#    'permanent wave',
#    'rock',
#    'spacegrunge']],
#  'Oasis': [['beatlesque', 'britpop', 'madchester', 'permanent wave', 'rock']],
#  'Aerosmith': [['album rock', 'classic rock', 'hard rock', 'rock']],
#  'Natalie Merchant': [['ectofolk', 'folk', 'lilith', 'singer-songwriter']],
#  'TLC': [['atl hip hop',
#    'contemporary r&b',
#    'dance pop',
#    'girl group',
#    'hip pop',
#    'r&b',
#    'urban contemporary']],
#  'Natalie Imbruglia': [['dance pop',
#    'europop',
#    'lilith',
#    'new wave pop',
#    'pop rock']],
#  'Lisa Loeb & Nine Stories': [['lilith', 'pop rock']],
#  'Toni Braxton': [['contemporary r&b',
#    'dance pop',
#    'r&b',
#    'urban contemporary']],
#  'Sarah McLachlan': [['canadian pop',
#    'canadian singer-songwriter',
#    'ectofolk',
#    'lilith',
#    'permanent wave',
#    'pop rock']],
#  'The Verve': [['britpop', 'permanent wave', 'rock', 'shoegaze']],
#  'Soul Asylum': [['alternative rock',
#    'grunge',
#    'permanent wave',
#    'pop rock',
#    'post-grunge']],
#  'The Verve Pipe': [['pop rock', 'post-grunge']],
#  'Dido': [['dance pop', 'europop', 'lilith', 'neo mellow', 'pop rock']],
#  'Sade': [['british soul', 'sophisti-pop']],
#  'DNA': [[]],
#  'Hootie & The Blowfish': [['heartland rock', 'pop rock', 'post-grunge']],
#  'Cali Swag District': [['pop rap']],
#  'LMFAO': [['dance pop', 'pop', 'pop rap']],
#  'Vanilla Ice': [['miami hip hop']],
#  'The Isley Brothers': [['classic soul',
#    'funk',
#    'motown',
#    'quiet storm',
#    'soul']],
#  'Flo Rida': [['dance pop', 'miami hip hop', 'pop', 'pop rap']],
#  'Michael Jackson': [['r&b', 'soul']],
#  'Sir Mix-A-Lot': [['old school hip hop']],
#  'P!nk': [['dance pop', 'pop']],
#  'Mr. C The Slide Man': [['kids dance party']],
#  'Neil Diamond': [['adult standards',
#    'brill building pop',
#    'folk rock',
#    'heartland rock',
#    'mellow gold',
#    'singer-songwriter',
#    'soft rock',
#    'yacht rock']],
#  'Cupid': [['kids dance party']],
#  'Lady Gaga': [['art pop', 'dance pop', 'pop']],
#  'Daft Punk': [['electro', 'filter house', 'rock']],
#  'Pitbull': [['dance pop', 'miami hip hop', 'pop']],
#  'Rihanna': [['barbadian pop', 'pop', 'urban contemporary']],
#  'Train': [['dance pop', 'neo mellow', 'pop', 'pop rock']],
#  'Nicki Minaj': [['hip pop', 'pop', 'queens hip hop', 'rap']],
#  'Wild Cherry': [['disco', 'funk rock']],
#  'Old School Players': [[]],
#  'Will Smith': [['hip hop', 'pop rap']],
#  'Bob Marley & The Wailers': [['reggae', 'roots reggae']],
#  'Ed Sheeran': [['pop', 'singer-songwriter pop', 'uk pop']],
#  'Bruno Mars': [['dance pop', 'pop']],
#  'Edwin McCain': [['neo mellow', 'pop rock']],
#  'Jason Mraz': [['acoustic pop', 'dance pop', 'neo mellow', 'pop']],
#  'Sixpence None The Richer': [['lilith', 'pop rock']],
#  'American Authors': [['modern rock', 'pop rock']],
#  'K-Ci & JoJo': [['contemporary r&b', 'r&b', 'urban contemporary']],
#  'Toploader': [['british alternative rock']],
#  'Colbie Caillat': [['dance pop', 'neo mellow', 'pop']],
#  'Dave Matthews Band': [['jam band', 'neo mellow', 'pop rock']],
#  'Rascal Flatts': [['contemporary country', 'country', 'country road']],
#  'Tom Petty and the Heartbreakers': [['album rock',
#    'classic rock',
#    'hard rock',
#    'heartland rock',
#    'mellow gold',
#    'rock',
#    'singer-songwriter',
#    'soft rock']],
#  'Taio Cruz': [['dance pop', 'pop', 'pop rap']],
#  'Tiësto': [['big room',
#    'brostep',
#    'dutch edm',
#    'edm',
#    'house',
#    'pop dance',
#    'slap house',
#    'trance']],
#  'The Lumineers': [['folk-pop', 'modern rock', 'stomp and holler']],
#  'House Of Pain': [['gangster rap', 'hip hop', 'rap rock', 'west coast rap']],
#  'Kris Kross': [['gangster rap',
#    'hardcore hip hop',
#    'hip hop',
#    'hip pop',
#    'old school atlanta hip hop']],
#  'Next': [['boy band',
#    'contemporary r&b',
#    'minneapolis sound',
#    'new jack swing',
#    'r&b',
#    'urban contemporary']],
#  'Florida Georgia Line': [['contemporary country',
#    'country',
#    'country pop',
#    'country road',
#    'modern country rock']],
#  'Clean Bandit': [['pop', 'uk dance', 'uk funky']],
#  'MKTO': [['pop', 'post-teen pop']],
#  'Charli XCX': [['art pop', 'candy pop', 'metropopolis', 'pop', 'uk pop']],
#  'Calvin Harris': [['dance pop',
#    'edm',
#    'electro house',
#    'house',
#    'pop',
#    'pop dance',
#    'progressive house',
#    'uk dance']],
#  'Becky G': [['latin pop',
#    'latin viral pop',
#    'rap latina',
#    'reggaeton',
#    'trap latino',
#    'urbano latino']],
#  'Ariana Grande': [['pop']],
#  'Macklemore & Ryan Lewis': [['pop rap', 'seattle hip hop']],
#  'The Aranbee Pop Symphony Orchestra': [[]],
#  'STRFKR': [['indie rock', 'indietronica']],
#  '311': [['alternative metal',
#    'alternative rock',
#    'funk metal',
#    'funk rock',
#    'nu metal',
#    'pop rock',
#    'rap rock',
#    'reggae fusion']],
#  'Nathaniel Rateliff & The Night Sweats': [['indie folk',
#    'modern blues rock',
#    'new americana',
#    'stomp and holler']],
#  'Toadies': [['alternative rock', 'grunge', 'pop rock', 'post-grunge']],
#  'Queens of the Stone Age': [['alternative metal',
#    'alternative rock',
#    'grunge',
#    'modern rock',
#    'palm desert scene',
#    'rock',
#    'stoner metal',
#    'stoner rock']],
#  'The Cranberries': [['irish rock', 'pop rock', 'rock']],
#  'Misfits': [['horror punk',
#    'new jersey hardcore',
#    'new jersey punk',
#    'punk']],
#  'Willy Moon': [['shimmer pop']],
#  'The Flys': [['post-grunge']],
#  'Tame Impala': [['australian psych',
#    'modern rock',
#    'neo-psychedelic',
#    'rock']],
#  'Sia': [['australian dance', 'australian pop', 'pop']],
#  'Arctic Monkeys': [['garage rock',
#    'modern rock',
#    'permanent wave',
#    'rock',
#    'sheffield indie']],
#  'Fink': [['indie folk']],
#  'James Vincent McMorrow': [['chamber pop',
#    'indie folk',
#    'irish singer-songwriter',
#    'stomp and holler']],
#  'VÉRITÉ': [['alt z',
#    'brooklyn indie',
#    'dark pop',
#    'electropop',
#    'indie poptimism',
#    'metropopolis',
#    'nyc pop',
#    'vapor pop']],
#  'dvsn': [['canadian contemporary r&b', 'r&b']],
#  'Starley': [['aussietronica']],
#  'HAIM': [['indietronica', 'metropopolis']],
#  'Kiiara': [['alt z', 'electropop']],
#  'Tash Sultana': [['australian reggae fusion']],
#  'Thomston': [['etherpop', 'indie electropop', 'indie poptimism']],
#  'Oh Wonder': [['electropop', 'indie poptimism', 'pov: indie']],
#  'BANKS': [['art pop',
#    'electropop',
#    'indie poptimism',
#    'indietronica',
#    'shimmer pop']],
#  'Diddy': [['dance pop',
#    'east coast hip hop',
#    'hip hop',
#    'hip pop',
#    'pop rap',
#    'rap']],
#  'Flume': [['australian dance',
#    'australian electropop',
#    'australian indie',
#    'downtempo',
#    'edm',
#    'indietronica']],
#  'Niia': [[]],
#  'Halsey': [['electropop', 'etherpop', 'indie poptimism', 'pop']],
#  'Elliot Moss': [['nyc pop']],
#  'The Kite String Tangle': [['aussietronica',
#    'australian indie',
#    'brisbane indie']],
#  'London Grammar': [['metropopolis', 'nottingham indie']],
#  'Childish Gambino': [['atl hip hop', 'hip hop', 'rap']],
#  'LANY': [['la pop', 'opm']],
#  'Francis and the Lights': [['art pop']],
#  'Water Park': [[]],
#  'Joe Goddard': [['electronica', 'indie soul', 'nu disco']],
#  'Stereophonics': [['britpop', 'welsh rock']],
#  'Rudimental': [['pop dance', 'uk dance', 'uk funky']],
#  'Stateless': [['british alternative rock']],
#  'The Paper Kites': [['australian indie folk',
#    'indie anthem-folk',
#    'indie folk',
#    'stomp and flutter',
#    'stomp and holler']],
#  'Yeo': [[]],
#  'GOSTO': [['dutch pop']],
#  'Sol Rising': [['world devotional']],
#  'Dagny': [['norwegian pop']],
#  'Bonobo': [['downtempo',
#    'electronica',
#    'indietronica',
#    'instrumental hip hop',
#    'jazztronica',
#    'nu jazz',
#    'trip hop']],
#  'Gotts Street Park': [['british soul']],
#  'Rhye': [['art pop',
#    'downtempo',
#    'indie soul',
#    'indietronica',
#    'shimmer pop']],
#  'Aquilo': [['indie anthem-folk']],
#  'BASECAMP': [['vapor soul']],
#  'Bruno Major': [['singer-songwriter pop']],
#  'Alpines': [['shimmer pop']],
#  'James Hersey': [[]],
#  'Jessie J': [['dance pop', 'pop']],
#  'Disclosure': [['edm', 'house', 'indietronica', 'uk dance']],
#  'George Maple': [['australian pop']],
#  'DeJ Loaf': [['detroit hip hop', 'r&b', 'trap', 'trap queen']],
#  'Great Good Fine Ok': [['hopebeat',
#    'indie poptimism',
#    'metropopolis',
#    'neo-synthpop',
#    'nyc pop']],
#  'John Splithoff': [['nyc pop']],
#  'Asta': [['australian indie']],
#  'Charlie Puth': [['pop', 'viral pop']],
#  'Fred V & Grafix': [['dancefloor dnb', 'drum and bass', 'liquid funk']],
#  'Catfish and the Bottlemen': [['modern alternative rock',
#    'modern rock',
#    'stomp pop',
#    'welsh rock']],
#  'Cage The Elephant': [['modern alternative rock',
#    'modern rock',
#    'pov: indie',
#    'punk blues',
#    'rock']],
#  'Red Hot Chili Peppers': [['alternative rock',
#    'funk metal',
#    'funk rock',
#    'permanent wave',
#    'rock']],
#  'Cold War Kids': [['indie rock',
#    'modern alternative rock',
#    'modern rock',
#    'piano rock',
#    'stomp and holler']],
#  'Kings of Leon': [['modern rock', 'rock']],
#  'Florence + The Machine': [['baroque pop',
#    'electropop',
#    'modern rock',
#    'uk alternative pop']],
#  'The Beatles': [['british invasion',
#    'classic rock',
#    'merseybeat',
#    'psychedelic rock',
#    'rock']],
#  'Green Day': [['modern rock', 'permanent wave', 'punk', 'rock']],
#  'Lord Huron': [['indie folk', 'stomp and holler']],
#  'Portugal. The Man': [['indie rock',
#    'indietronica',
#    'modern alternative rock',
#    'modern rock']],
#  'alt-J': [['indie rock',
#    'indietronica',
#    'modern alternative rock',
#    'modern rock',
#    'rock']],
#  'GROUPLOVE': [['indie rock',
#    'la indie',
#    'modern alternative rock',
#    'modern rock',
#    'pov: indie']],
#  'Gorillaz': [['alternative hip hop', 'modern rock', 'rock']],
#  'Electric Light Orchestra': [['album rock',
#    'art rock',
#    'beatlesque',
#    'classic rock',
#    'glam rock',
#    'mellow gold',
#    'rock',
#    'soft rock',
#    'symphonic rock']],
#  'Dirty Heads': [['reggae fusion', 'reggae rock']],
#  'UB40': [['reggae fusion', 'uk reggae']],
#  'Death Cab for Cutie': [['alternative rock',
#    'canadian indie',
#    'chamber pop',
#    'indie rock',
#    'indietronica',
#    'modern rock',
#    'seattle indie',
#    'washington indie']],
#  'The Monkees': [['album rock',
#    'beatlesque',
#    'bubblegum pop',
#    'classic rock',
#    'folk rock',
#    'heartland rock',
#    'mellow gold',
#    'psychedelic rock',
#    'rock',
#    'rock-and-roll',
#    'singer-songwriter',
#    'soft rock',
#    'sunshine pop']],
#  'Noah Kahan': [['pov: indie']],
#  'Willie Nelson': [['classic country pop',
#    'classic texas country',
#    'country',
#    'country rock',
#    'nashville sound',
#    'outlaw country',
#    'singer-songwriter']],
#  'The Cadillac Three': [['modern country rock', 'modern southern rock']],
#  'Chris Lane': [['contemporary country',
#    'country',
#    'country road',
#    'modern country rock']],
#  'Travis Tritt': [['contemporary country',
#    'country',
#    'country road',
#    'outlaw country']],
#  'Alan Jackson': [['country']],
#  'Wheeler Walker Jr.': [['outlaw country', 'redneck']],
#  'Whiskey Myers': [['classic texas country', 'modern southern rock']],
#  'Jason Boland & The Stragglers': [['classic texas country',
#    'outlaw country',
#    'red dirt',
#    'texas country']],
#  'Cody Johnson': [['classic texas country',
#    'contemporary country',
#    'modern country pop']],
#  'Merle Haggard': [['bakersfield sound',
#    'country',
#    'country rock',
#    'nashville sound',
#    'outlaw country']],
#  'David Allan Coe': [['country', 'outlaw country']],
#  'Mark Chesnutt': [['country', 'country road']],
#  'Gary Stewart': [['classic country pop',
#    'classic texas country',
#    'outlaw country']],
#  'Merle Haggard & The Strangers': [['bakersfield sound']],
#  'Clint Black': [['contemporary country', 'country', 'country road']],
#  'Brooks & Dunn': [['contemporary country', 'country', 'country road']],
#  'Josh Turner': [['contemporary country', 'country', 'country road']],
#  'Midland': [['classic texas country', 'neo-traditional country']],
#  'Post Malone': [['dfw rap', 'melodic rap', 'pop', 'rap']],
#  'Chance the Rapper': [['chicago rap',
#    'conscious hip hop',
#    'hip hop',
#    'pop rap',
#    'rap',
#    'trap']],
#  'Jeremih': [['chicago rap',
#    'pop rap',
#    'r&b',
#    'southern hip hop',
#    'trap',
#    'urban contemporary']],
#  'Lil Wayne': [['hip hop', 'new orleans rap', 'pop rap', 'rap', 'trap']],
#  'Lupe Fiasco': [['chicago rap',
#    'conscious hip hop',
#    'hip hop',
#    'political hip hop',
#    'pop rap',
#    'rap',
#    'southern hip hop']],
#  'Desiigner': [['pop rap', 'rap', 'southern hip hop', 'trap', 'viral trap']],
#  'Wale': [['pop rap', 'r&b', 'rap', 'southern hip hop', 'trap']],
#  'Migos': [['atl hip hop', 'hip hop', 'pop rap', 'rap', 'trap']],
#  'Drake': [[]],
#  'Big Sean': [['detroit hip hop',
#    'hip hop',
#    'pop rap',
#    'r&b',
#    'rap',
#    'southern hip hop',
#    'trap']],
#  'Bryson Tiller': [['kentucky hip hop', 'r&b', 'rap']],
#  'YG': [[]],
#  'Meek Mill': [['hip hop',
#    'philly rap',
#    'pop rap',
#    'rap',
#    'southern hip hop',
#    'trap']],
#  'Timbaland': [['dance pop', 'pop', 'pop rap']],
#  'ScHoolboy Q': [['gangster rap',
#    'hip hop',
#    'pop rap',
#    'rap',
#    'southern hip hop',
#    'trap']],
#  'blackbear': [['pop']],
#  'J. Cole': [['conscious hip hop',
#    'hip hop',
#    'north carolina hip hop',
#    'rap']],
#  'A Boogie Wit da Hoodie': [['melodic rap', 'rap', 'trap']],
#  'Travis Scott': [['hip hop', 'rap', 'slap house']],
#  'mansionz': [['indie pop rap']],
#  'Russ': [['hawaiian hip hop', 'pop rap']],
#  'Kendrick Lamar': [['conscious hip hop', 'hip hop', 'rap', 'west coast rap']],
#  'Aminé': [['pop rap', 'portland hip hop', 'rap', 'underground hip hop']],
#  'Cardi B': [['pop', 'rap']],
#  'Juicy J': [['crunk',
#    'memphis hip hop',
#    'pop rap',
#    'rap',
#    'southern hip hop',
#    'trap']],
#  'Macklemore': [['pop rap', 'seattle hip hop']],
#  'Rae Sremmurd': [['melodic rap',
#    'mississippi hip hop',
#    'pop rap',
#    'rap',
#    'trap']],
#  'Fort Minor': [['rap rock']],
#  'Quinn XCII': [['indie pop rap']],
#  'Kevin Gates': [['baton rouge rap', 'rap', 'southern hip hop', 'trap']],
#  'Bobby Shmurda': [['nyc rap', 'rap', 'trap']],
#  'Kodak Black': [['florida drill',
#    'florida rap',
#    'melodic rap',
#    'miami hip hop',
#    'rap',
#    'trap',
#    'trap latino']],
#  'Lil Dicky': [['comedy rap', 'indie pop rap', 'pop rap']],
#  'Tee Grizzley': [['detroit hip hop',
#    'detroit trap',
#    'rap',
#    'southern hip hop',
#    'trap']],
#  'PnB Rock': [['melodic rap', 'rap', 'trap']],
#  'French Montana': [['hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap']],
#  'Plies': [['dirty south rap', 'miami hip hop', 'southern hip hop', 'trap']],
#  'mike.': [['indie pop rap', 'rhode island rap']],
#  'AJR': [['pov: indie']],
#  'Natural Self': [['electro jazz', 'funky breaks', 'nu jazz']],
#  'Spoon': [['alternative rock', 'austindie', 'indie rock', 'modern rock']],
#  'Michna': [[]],
#  'Pretty Lights': [['glitch hop', 'jazztronica', 'livetronica']],
#  'Erykah Badu': [['afrofuturism', 'alternative r&b', 'neo soul', 'r&b']],
#  'Kavinsky': [['filter house']],
#  'Little Dragon': [['art pop',
#    'chillwave',
#    'downtempo',
#    'electronica',
#    'gothenburg indie',
#    'indie soul',
#    'indietronica',
#    'neo-synthpop',
#    'swedish electropop',
#    'swedish synthpop',
#    'trip hop']],
#  'Jens Buchert': [['chill lounge',
#    'deep chill',
#    'future ambient',
#    'german electronica']],
#  'Zero 7': [['downtempo', 'electronica', 'trip hop']],
#  'Lotus': [[]],
#  'Oakman': [[]],
#  'Handsome Boy Modeling School': [['alternative hip hop', 'trip hop']],
#  'Lykke Li': [['electropop',
#    'indietronica',
#    'neo-synthpop',
#    'swedish electropop',
#    'swedish indie pop',
#    'swedish pop']],
#  'Flying Lotus feat. Andreya Triana': [[]],
#  'Cooly G': [['electra', 'footwork']],
#  'Miguel': [['r&b', 'urban contemporary']],
#  'C2C': [['nantes indie', 'turntablism']],
#  'X Ambassadors': [['modern alternative rock', 'modern rock', 'stomp pop']],
#  'DJ Shadow': [['downtempo',
#    'electronica',
#    'instrumental hip hop',
#    'trip hop']],
#  'DJ Cam': [['downtempo', 'instrumental hip hop', 'trip hop']],
#  'deadmau5': [['canadian electronic',
#    'edm',
#    'electro house',
#    'pop dance',
#    'progressive house']],
#  'Wax Tailor': [['electronica',
#    'hip-hop experimental',
#    'nu jazz',
#    'trip hop']],
#  'Massive Attack': [['downtempo', 'electronica', 'trip hop']],
#  'Ellie Goulding': [['indietronica', 'metropopolis', 'pop', 'uk pop']],
#  'RJD2': [['electronica', 'instrumental hip hop', 'jazztronica']],
#  'TOKiMONSTA': [['chillwave',
#    'electra',
#    'escape room',
#    'indietronica',
#    'instrumental hip hop',
#    'wonky']],
#  'The Pharcyde': [['alternative hip hop',
#    'hardcore hip hop',
#    'hip hop',
#    'jazz rap',
#    'west coast rap']],
#  'La Roux': [['alternative dance',
#    'electropop',
#    'indietronica',
#    'neo-synthpop']],
#  'Incubus': [['alternative metal',
#    'alternative rock',
#    'funk metal',
#    'funk rock',
#    'nu metal',
#    'post-grunge',
#    'rock']],
#  'Flying Lotus': [['afrofuturism',
#    'alternative hip hop',
#    'electronica',
#    'escape room',
#    'experimental hip hop',
#    'glitch',
#    'glitch hop',
#    'indietronica',
#    'instrumental hip hop',
#    'intelligent dance music',
#    'jazztronica',
#    'psychedelic hip hop',
#    'wonky']],
#  'Goapele': [['neo soul', 'r&b', 'urban contemporary']],
#  'The xx': [['downtempo', 'dream pop', 'indietronica']],
#  'Tricky': [['electronica', 'trip hop']],
#  'Daedelus': [['glitch hop', 'intelligent dance music', 'wonky']],
#  'AlunaGeorge': [['electropop', 'house', 'uk dance']],
#  'Télépopmusik': [['downtempo', 'electronica', 'trip hop']],
#  'Balam Acab': [['chillwave', 'grave wave', 'witch house', 'wonky']],
#  'The Weeknd': [['canadian contemporary r&b', 'canadian pop', 'pop']],
#  'Holy Other': [['chillwave',
#    'future garage',
#    'grave wave',
#    'witch house',
#    'wonky']],
#  'The Avalanches': [['alternative dance',
#    'australian alternative rock',
#    'australian dance',
#    'collage pop',
#    'electronica',
#    'indietronica',
#    'new rave',
#    'psychedelic hip hop']],
#  'Major Lazer': [['dance pop',
#    'edm',
#    'electro house',
#    'moombahton',
#    'pop',
#    'pop dance']],
#  'Passion Pit': [['indie rock',
#    'indietronica',
#    'modern rock',
#    'neo-synthpop',
#    'shimmer pop']],
#  'Hooverphonic': [['downtempo', 'electronica', 'trip hop']],
#  'Flight Facilities': [['aussietronica',
#    'australian dance',
#    'australian indie',
#    'indietronica',
#    'nu disco']],
#  'Populous': [['indie electronica',
#    'italian electronica',
#    'latintronica',
#    'pop electronico',
#    'puglia indie']],
#  'Blackmill': [['chillstep', 'dubstep product', 'substep']],
#  'Pantyraid': [['glitch hop']],
#  'Morcheeba': [['downtempo', 'electronica', 'trip hop']],
#  'Portishead': [['alternative rock',
#    'art pop',
#    'dark pop',
#    'electronica',
#    'laboratorio',
#    'trip hop']],
#  'Air': [['ambient pop',
#    'downtempo',
#    'electronica',
#    'indietronica',
#    'trip hop']],
#  'A Tribe Called Quest': [['conscious hip hop',
#    'east coast hip hop',
#    'golden age hip hop',
#    'hip hop',
#    'jazz rap',
#    'queens hip hop']],
#  'Blue Foundation': [['dream pop']],
#  'Washed Out': [['chillwave', 'indietronica', 'neo-synthpop']],
#  'Burial': [['classic dubstep',
#    'electronica',
#    'future garage',
#    'hauntology',
#    'intelligent dance music',
#    'trip hop',
#    'uk bass',
#    'wonky']],
#  'Blackbird Blackbird': [['chillwave', 'indietronica', 'shimmer pop']],
#  'Tourist': [['chillwave',
#    'future garage',
#    'indie soul',
#    'indietronica',
#    'vapor soul']],
#  'Kanye West': [['chicago rap', 'hip hop', 'rap']],
#  'Beach House': [['baltimore indie',
#    'dream pop',
#    'dreamo',
#    'indie rock',
#    'indietronica',
#    'modern dream pop',
#    'pov: indie']],
#  'Four Tet': [['electronica',
#    'folktronica',
#    'indietronica',
#    'intelligent dance music',
#    'trip hop']],
#  'Thievery Corporation': [['downtempo',
#    'electronica',
#    'livetronica',
#    'trip hop']],
#  'Tripssono': [['coverchill']],
#  'SBTRKT': [['chillwave',
#    'electronica',
#    'future garage',
#    'indie soul',
#    'indietronica']],
#  'The Roots': [['conscious hip hop',
#    'east coast hip hop',
#    'hip hop',
#    'philly rap',
#    'political hip hop']],
#  'Peter Bjorn and John': [['alternative dance',
#    'baroque pop',
#    'dance-punk',
#    'indie rock',
#    'modern rock',
#    'new rave',
#    'swedish alternative rock',
#    'swedish indie pop']],
#  'The Naked And Famous': [['auckland indie',
#    'indietronica',
#    'kiwi rock',
#    'metropopolis']],
#  'Afterlife': [['chill lounge']],
#  'Fort Fairfield': [[]],
#  'Bliss': [['chill lounge', 'world chill']],
#  'Andreya Triana': [['british soul']],
#  'Mr Twin Sister': [['chillwave']],
#  'Baths': [['chillwave', 'indietronica', 'shimmer pop', 'wonky']],
#  'Cut Chemist': [['scratch', 'trip hop', 'turntablism']],
#  'Deltron 3030': [['abstract hip hop',
#    'afrofuturism',
#    'alternative hip hop',
#    'psychedelic hip hop']],
#  'Jamie xx': [['electronica', 'future garage', 'indie soul', 'indietronica']],
#  'Feed Me': [['brostep', 'complextro', 'edm', 'electro house', 'filthstep']],
#  'Georgia Anne Muldrow': [['alternative r&b', 'instrumental hip hop']],
#  'Paper Diamond': [['glitch hop']],
#  'Robert Glasper': [['contemporary jazz',
#    'indie soul',
#    'jazz',
#    'modern jazz piano',
#    'neo r&b',
#    'neo soul']],
#  'Michal Menert': [['downtempo bass', 'glitch hop']],
#  'Crystal Castles': [['alternative dance',
#    'bitpop',
#    'digital hardcore',
#    'indietronica',
#    'neo-synthpop',
#    'new rave',
#    'nintendocore']],
#  'InContext': [[]],
#  'Adventure Club': [['brostep',
#    'canadian electronic',
#    'complextro',
#    'edm',
#    'electro house',
#    'filthstep',
#    'pop dance']],
#  'TwoThirds': [['chillstep', 'gaming edm']],
#  'Phantogram': [['indietronica', 'metropopolis', 'neo-synthpop']],
#  'Feist': [[]],
#  'Cults': [['experimental pop', 'indie surf', 'pov: indie']],
#  'Gold Panda': [['chillwave',
#    'electronica',
#    'future garage',
#    'indietronica',
#    'microhouse',
#    'wonky']],
#  'Long Beach Dub Allstars': [['reggae rock']],
#  'Kid Cudi': [['hip hop', 'ohio hip hop', 'pop rap', 'rap']],
#  'Yael Naim': [['folk-pop']],
#  'Passenger': [['folk-pop', 'neo mellow']],
#  'Milky Chance': [['german pop', 'modern rock']],
#  'Young Thug': [['atl hip hop',
#    'atl trap',
#    'gangster rap',
#    'melodic rap',
#    'rap',
#    'trap']],
#  'James Bay': [['neo mellow', 'pop', 'uk pop']],
#  'Lost Frequencies': [['belgian edm', 'edm', 'pop dance', 'tropical house']],
#  'Wiz Khalifa': [['hip hop',
#    'pittsburgh rap',
#    'pop rap',
#    'rap',
#    'southern hip hop',
#    'trap']],
#  'Tom Jones': [['adult standards', 'british invasion']],
#  'Alessia Cara': [['canadian contemporary r&b', 'canadian pop', 'pop']],
#  'Ruth B.': [['alt z', 'canadian contemporary r&b', 'canadian pop', 'pop']],
#  'Cam': [['contemporary country', 'modern country rock']],
#  'Rob Thomas': [['neo mellow', 'pop rock', 'post-grunge']],
#  'Jeffrey James': [[]],
#  'Jasmine Thompson': [['viral pop']],
#  'Gabrielle Aplin': [['acoustic pop',
#    'indie anthem-folk',
#    'neo-singer-songwriter',
#    'uk pop',
#    'viral pop']],
#  'Christina Perri': [['pop']],
#  'Molly Kate Kestner': [['alt z', 'lds youth']],
#  'Katy McAllister': [['piano rock', 'viral pop']],
#  'Joseph Vincent': [['viral pop']],
#  'James Arthur': [['pop', 'talent show', 'uk pop']],
#  'Alanis Morissette': [['canadian pop',
#    'canadian singer-songwriter',
#    'lilith',
#    'neo mellow',
#    'pop rock',
#    'singer-songwriter']],
#  'Alice In Chains': [['alternative metal',
#    'alternative rock',
#    'grunge',
#    'hard rock',
#    'nu metal',
#    'rock']],
#  'Barenaked Ladies': [['canadian pop',
#    'canadian rock',
#    'pop rock',
#    'post-grunge']],
#  'Beck': [['alternative rock', 'anti-folk', 'permanent wave', 'rock']],
#  'Better Than Ezra': [['pop rock', 'post-grunge']],
#  'The Black Crowes': [['album rock',
#    'blues rock',
#    'classic rock',
#    'electric blues',
#    'hard rock',
#    'heartland rock',
#    'jam band',
#    'rock',
#    'southern rock']],
#  'Blind Melon': [['alternative metal',
#    'alternative rock',
#    'grunge',
#    'pop rock',
#    'rock']],
#  'Blues Traveler': [['heartland rock', 'jam band', 'pop rock', 'post-grunge']],
#  'Bush': [['alternative metal',
#    'alternative rock',
#    'grunge',
#    'nu metal',
#    'pop rock',
#    'post-grunge',
#    'rock']],
#  'Candlebox': [['alternative metal', 'grunge', 'nu metal', 'post-grunge']],
#  'Chumbawamba': [['anarcho-punk']],
#  'Counting Crows': [['neo mellow', 'pop rock', 'post-grunge', 'rock']],
#  'Coyote Shivers': [[]],
#  'Crazy Town': [['alternative metal',
#    'funk metal',
#    'nu metal',
#    'post-grunge',
#    'rap rock']],
#  'Duncan Sheik': [['pop rock']],
#  'Eagle-Eye Cherry': [['pop rock']],
#  'Eve 6': [['alternative metal', 'pop rock', 'post-grunge']],
#  'Everclear': [['alternative metal',
#    'alternative rock',
#    'nu metal',
#    'permanent wave',
#    'pop rock',
#    'post-grunge']],
#  'Everything': [[]],
#  'Filter': [['alternative metal',
#    'alternative rock',
#    'grunge',
#    'industrial metal',
#    'nu metal',
#    'post-grunge']],
#  'Fiona Apple': [['art pop',
#    'chamber pop',
#    'dark pop',
#    'lilith',
#    'permanent wave',
#    'piano rock',
#    'singer-songwriter']],
#  'Foo Fighters': [['alternative metal',
#    'alternative rock',
#    'modern rock',
#    'permanent wave',
#    'post-grunge',
#    'rock']],
#  'Fuel': [['alternative metal', 'nu metal', 'post-grunge']],
#  'Gin Blossoms': [['permanent wave',
#    'pop rock',
#    'post-grunge',
#    'tempe indie']],
#  'The Goo Goo Dolls': [['neo mellow',
#    'permanent wave',
#    'pop rock',
#    'post-grunge']],
#  'Harvey Danger': [['pop rock', 'post-grunge']],
#  "Jane's Addiction": [['alternative metal',
#    'alternative rock',
#    'funk metal',
#    'funk rock',
#    'grunge',
#    'nu metal',
#    'permanent wave',
#    'rock']],
#  'Live': [['grunge', 'pop rock', 'post-grunge']],
#  'Matchbox Twenty': [['neo mellow', 'pop rock', 'post-grunge']],
#  'Mazzy Star': [['dream pop', 'melancholia', 'shoegaze', 'slowcore']],
#  'Nine Inch Nails': [['alternative metal',
#    'alternative rock',
#    'cyberpunk',
#    'electronic rock',
#    'industrial',
#    'industrial metal',
#    'industrial rock',
#    'nu metal',
#    'post-grunge',
#    'rock']],
#  'Nirvana': [['grunge', 'permanent wave', 'rock']],
#  'No Doubt': [['dance pop',
#    'dance rock',
#    'permanent wave',
#    'pop rock',
#    'rock']],
#  'The Offspring': [['alternative metal',
#    'permanent wave',
#    'post-grunge',
#    'punk',
#    'rock',
#    'skate punk',
#    'socal pop punk']],
#  'Pearl Jam': [['alternative metal',
#    'alternative rock',
#    'classic rock',
#    'grunge',
#    'hard rock',
#    'permanent wave',
#    'rock']],
#  'R.E.M.': [['alternative rock', 'athens indie', 'permanent wave', 'rock']],
#  'Smash Mouth': [['pop rock', 'post-grunge']],
#  'Soundgarden': [['alternative metal',
#    'alternative rock',
#    'classic rock',
#    'grunge',
#    'hard rock',
#    'nu metal',
#    'rock']],
#  'Spin Doctors': [['pop rock', 'post-grunge']],
#  'Sublime': [['rap rock', 'reggae fusion', 'ska mexicano', 'ska punk']],
#  'Sugar Ray': [['alternative metal', 'funk metal', 'pop rock', 'post-grunge']],
#  'Third Eye Blind': [['alternative metal',
#    'alternative rock',
#    'pop rock',
#    'post-grunge']],
#  'Tonic': [['pop rock', 'post-grunge']],
#  'Vertical Horizon': [['neo mellow', 'pop rock', 'post-grunge']],
#  'The Wallflowers': [['pop rock', 'post-grunge']],
#  'Sylvan Esso': [['art pop',
#    'chamber pop',
#    'etherpop',
#    'indie pop',
#    'indie rock',
#    'indietronica',
#    'shimmer pop']],
#  'Gregory Alan Isakov': [['indie folk',
#    'pop folk',
#    'stomp and flutter',
#    'stomp and holler']],
#  'Whilk & Misky': [['uk alternative pop']],
#  'Young the Giant': [['indietronica',
#    'modern alternative rock',
#    'modern rock',
#    'pov: indie',
#    'stomp and holler']],
#  'Sleater-Kinney': [['alternative rock',
#    'indie rock',
#    'noise pop',
#    'olympia wa indie',
#    'riot grrrl']],
#  'Teenage Fanclub': [['alternative rock',
#    'modern power pop',
#    'power pop',
#    'scottish indie',
#    'scottish rock',
#    'shoegaze']],
#  'The Shins': [['albuquerque indie',
#    'alternative rock',
#    'canadian indie',
#    'chamber pop',
#    'indie pop',
#    'indie rock',
#    'modern rock',
#    'portland indie',
#    'seattle indie',
#    'stomp and holler']],
#  'Bishop Briggs': [['modern alternative rock']],
#  'Angel Olsen': [['alternative americana',
#    'art pop',
#    'chamber pop',
#    'countrygaze',
#    'dream pop',
#    'experimental pop',
#    'indie pop',
#    'indie rock',
#    'noise pop',
#    'singer-songwriter']],
#  '✝✝✝ (Crosses)': [['electronic rock']],
#  'BROODS': [['auckland indie',
#    'etherpop',
#    'indietronica',
#    'metropopolis',
#    'nz pop']],
#  'Cloud Nothings': [['cleveland indie',
#    'indie punk',
#    'indie rock',
#    'lo-fi',
#    'modern power pop',
#    'noise pop',
#    'noise rock',
#    'popgaze']],
#  'Sum 41': [['alternative metal',
#    'canadian pop punk',
#    'canadian punk',
#    'modern rock',
#    'pop punk',
#    'post-grunge',
#    'punk',
#    'rock']],
#  'Adolescents': [['hardcore punk', 'punk']],
#  'Arcade Fire': [['alternative rock',
#    'baroque pop',
#    'canadian indie',
#    'canadian indie rock',
#    'chamber pop',
#    'indie rock',
#    'indietronica',
#    'modern rock',
#    'permanent wave',
#    'quebec indie',
#    'rock']],
#  'John Mayer': [['neo mellow', 'singer-songwriter']],
#  'The Black Keys': [['alternative rock',
#    'blues rock',
#    'garage rock',
#    'indie rock',
#    'indietronica',
#    'modern blues rock',
#    'modern rock',
#    'punk blues',
#    'rock',
#    'roots rock']],
#  'Ryan Adams': [['alternative country',
#    'new americana',
#    'roots rock',
#    'singer-songwriter']],
#  'Night Riots': [['hopebeat',
#    'indie poptimism',
#    'modern alternative rock',
#    'modern rock']],
#  'Built To Spill': [['alternative rock',
#    'chamber pop',
#    'idaho indie',
#    'indie rock',
#    'lo-fi',
#    'noise rock']],
#  'The Twilight Sad': [['melancholia',
#    'scottish hush',
#    'scottish indie',
#    'shoegaze']],
#  'Flagship': [['charlotte nc indie']],
#  'The Front Bottoms': [['asbury park indie',
#    'emo',
#    'new jersey indie',
#    'pov: indie']],
#  'Placebo': [['alternative rock', 'britpop', 'permanent wave', 'rock']],
#  'KAYTRANADA': [['alternative r&b',
#    'escape room',
#    'indie soul',
#    'lgbtq+ hip hop']],
#  'Dashboard Confessional': [['emo', 'neon pop punk', 'pop punk', 'pop rock']],
#  'Nada Surf': [['power pop']],
#  'my bloody valentine': [['alternative rock',
#    'dream pop',
#    'noise pop',
#    'shoegaze']],
#  'The Clash': [['alternative rock', 'permanent wave', 'punk', 'rock']],
#  'Hippo Campus': [['minneapolis indie', 'modern rock', 'pov: indie']],
#  'The Airborne Toxic Event': [['la indie', 'metropopolis']],
#  'Thundercat': [['afrofuturism', 'indie soul']],
#  'Vinyl Theatre': [['hopebeat',
#    'indie poptimism',
#    'modern alternative rock',
#    'modern rock']],
#  'David Bowie': [['art rock',
#    'classic rock',
#    'glam rock',
#    'permanent wave',
#    'rock']],
#  'Interpol': [['alternative dance',
#    'alternative rock',
#    'indie rock',
#    'indietronica',
#    'modern rock',
#    'rock']],
#  'Real Estate': [['chamber pop',
#    'chillwave',
#    'dreamo',
#    'experimental pop',
#    'indie rock',
#    'indietronica',
#    'lo-fi',
#    'neo-psychedelic',
#    'new jersey indie',
#    'noise pop',
#    'shimmer pop']],
#  'Unknown Mortal Orchestra': [['art pop',
#    'indie rock',
#    'indie soul',
#    'indietronica',
#    'kiwi rock',
#    'neo-psychedelic',
#    'portland hip hop',
#    'psychedelic pop']],
#  'Lorde': [['art pop', 'metropopolis', 'nz pop', 'pop']],
#  'Common': [['alternative hip hop',
#    'chicago rap',
#    'conscious hip hop',
#    'hardcore hip hop',
#    'hip hop',
#    'political hip hop']],
#  'New Order': [['alternative rock',
#    'dance rock',
#    'madchester',
#    'new romantic',
#    'new wave',
#    'permanent wave',
#    'post-punk',
#    'synthpop',
#    'uk post-punk']],
#  'Lana Del Rey': [['art pop', 'pop']],
#  'Fleet Foxes': [['chamber pop',
#    'folk',
#    'indie folk',
#    'indie rock',
#    'indietronica',
#    'modern rock',
#    'seattle indie',
#    'singer-songwriter',
#    'stomp and holler']],
#  'Amy Winehouse': [['british soul', 'neo soul']],
#  'Zella Day': [['alt z', 'electropop', 'gauze pop', 'indie poptimism']],
#  'DREAMCAR': [['electronic rock']],
#  'Jack Garratt': [['uk alternative pop']],
#  'AFI': [['alternative metal',
#    'nu metal',
#    'pop punk',
#    'post-grunge',
#    'punk',
#    'screamo']],
#  'Broken Social Scene': [['alternative rock',
#    'baroque pop',
#    'canadian indie',
#    'canadian indie rock',
#    'canadian rock',
#    'indie rock',
#    'noise pop']],
#  'Frank Ocean': [['lgbtq+ hip hop', 'neo soul']],
#  'Kristin Kontrol': [['metropopolis']],
#  'Iggy Pop': [['alternative rock',
#    'glam rock',
#    'permanent wave',
#    'protopunk',
#    'rock']],
#  'Cold Showers': [['dark post-punk', 'grave wave']],
#  'Palmas': [[]],
#  'The Dig': [[]],
#  'Merchandise': [['garage psych']],
#  'Kwesi Foraes': [[]],
#  'Benjamin Gibbard': [[]],
#  'The Bluetones': [['britpop']],
#  'Whitney': [['chamber pop',
#    'chicago indie',
#    'countrygaze',
#    'indie pop',
#    'indie rock']],
#  'Chelsea Wolfe': [['dark pop',
#    'doomgaze',
#    'gaian doom',
#    'grave wave',
#    'sacramento indie']],
#  'Plastic Flowers': [['greek indie', 'shimmer psych']],
#  'Jay Som': [['art pop',
#    'bay area indie',
#    'bubblegrunge',
#    'indie pop',
#    'oakland indie',
#    'small room']],
#  'The National': [['chamber pop',
#    'indie folk',
#    'indie rock',
#    'indietronica',
#    'modern rock']],
#  'The Dangerous Summer': [['anthem emo',
#    'neon pop punk',
#    'pop emo',
#    'pop punk']],
#  'Radiohead': [['alternative rock',
#    'art rock',
#    'melancholia',
#    'oxford indie',
#    'permanent wave',
#    'rock']],
#  'Car Seat Headrest': [['furry', 'indie rock', 'pov: indie']],
#  'Allah-Las': [['indie surf', 'neo-psychedelic', 'noise pop']],
#  'Harry Styles': [['pop']],
#  'Hozier': [['irish singer-songwriter', 'modern rock', 'pov: indie']],
#  'Aloe Blacc': [['pop soul', 'r&b']],
#  'John Legend': [['neo soul', 'pop', 'pop soul', 'urban contemporary']],
#  'Pharrell Williams': [['dance pop', 'pop']],
#  'Mark Ronson': [['pop soul']],
#  'WALK THE MOON': [['dance rock',
#    'modern alternative rock',
#    'modern rock',
#    'neo mellow',
#    'pop rock']],
#  'Matisyahu': [['reggae fusion']],
#  'Jess Glynne': [['dance pop', 'pop', 'uk pop']],
#  'You Me At Six': [['modern alternative rock',
#    'modern rock',
#    'neon pop punk',
#    'pop emo',
#    'pop punk']],
#  'Meghan Trainor': [['hip pop', 'pop']],
#  'Nico & Vinz': [['afrobeats']],
#  'Avicii': [['dance pop', 'edm', 'pop', 'pop dance']],
#  'Itch': [[]],
#  'George Ezra': [['folk-pop', 'neo-singer-songwriter']],
#  'Imagine Dragons': [['modern rock', 'pop', 'rock']],
#  'OneRepublic': [['piano rock', 'pop']],
#  'Andy Grammer': [['neo mellow', 'post-teen pop', 'viral pop']],
#  'Adele': [['british soul', 'pop', 'pop soul', 'uk pop']],
#  'Bastille': [['metropopolis', 'modern rock', 'pop']],
#  'Panic! At The Disco': [['modern rock', 'pop']],
#  'Bleachers': [['indie pop', 'indie poptimism', 'modern rock', 'pov: indie']],
#  'Jason Gray': [['ccm', 'christian alternative rock', 'christian music']],
#  'Mary Lambert': [['neo mellow']],
#  'Sheppard': [['australian indie', 'australian pop', 'folk-pop']],
#  'Fall Out Boy': [['emo', 'modern rock', 'pop', 'rock']],
#  'Mumford & Sons': [['modern folk rock',
#    'modern rock',
#    'neo mellow',
#    'stomp and holler',
#    'uk americana']],
#  'Nine Days': [['pop rock']],
#  'Owl City': [['indietronica', 'pop']],
#  'The Downtown Fiction': [['neon pop punk', 'pixie', 'pop emo']],
#  'Fifth Harmony': [['girl group', 'pop', 'talent show']],
#  'Neon Trees': [['modern rock', 'neo mellow', 'pop rock', 'pov: indie']],
#  'Two Door Cinema Club': [['indie rock',
#    'indietronica',
#    'irish rock',
#    'modern alternative rock',
#    'modern rock',
#    'northern irish indie']],
#  'Bad Suns': [['la indie',
#    'modern alternative rock',
#    'modern rock',
#    'pov: indie']],
#  'Audien': [['edm',
#    'electro house',
#    'pop dance',
#    'pop edm',
#    'progressive electro house',
#    'progressive house']],
#  'The Darkness': [['glam metal', 'hard rock']],
#  'The Hooters': [['philly indie']],
#  'Atlas Genius': [['indietronica',
#    'modern alternative rock',
#    'modern rock',
#    'shimmer pop']],
#  'Martin Solveig': [['disco house',
#    'edm',
#    'electro house',
#    'filter house',
#    'house',
#    'pop dance',
#    'vocal house']],
#  'DNCE': [['dance pop', 'pop']],
#  'Bear Hands': [['brooklyn indie', 'shimmer pop']],
#  'Hillsong UNITED': [['ccm', 'christian music', 'world worship', 'worship']],
#  'The Royal Concept': [['shimmer pop',
#    'swedish alternative rock',
#    'swedish indie pop']],
#  'Beach Avenue': [[]],
#  'Built By Titan': [['cedm']],
#  'Astoria Kings': [[]],
#  'Anthem Lights': [['channel pop', 'viral pop']],
#  'Yellowcard': [['alternative metal',
#    'pop punk',
#    'post-grunge',
#    'socal pop punk']],
#  'Adam Martin': [[]],
# ...
#  'Avenged Sevenfold': [['alternative metal']],
#  'Deftones': [['alternative metal',
#    'nu metal',
#    'rap metal',
#    'rock',
#    'sacramento indie']],
#  'Killswitch Engage': [['alternative metal',
#    'boston metal',
#    'melodic metalcore',
#    'metalcore',
#    'nu metal',
#    'post-grunge']],
#  'Slipknot': [['alternative metal', 'nu metal', 'rap metal', 'rock']],
#  'Chevelle': [['alternative metal',
#    'christian rock',
#    'nu metal',
#    'post-grunge']],
#  'Five Finger Death Punch': [['alternative metal',
#    'groove metal',
#    'nu metal']],
#  'Metallica': [['hard rock',
#    'metal',
#    'old school thrash',
#    'rock',
#    'thrash metal']],
#  'Twenty One Pilots': [['modern rock', 'pop', 'pov: indie', 'rock']],
#  'Jon Bellion': [['indie pop rap']],
#  'ODESZA': [['chillwave', 'edm', 'indietronica']],
#  'Fetty Wap': [['new jersey rap',
#    'pop rap',
#    'rap',
#    'southern hip hop',
#    'trap']],
#  'Galantis': [['dance pop', 'edm', 'pop', 'pop dance']],
#  'DVBBS': [['canadian electronic',
#    'dutch house',
#    'edm',
#    'electro house',
#    'pop dance',
#    'progressive electro house',
#    'slap house']],
#  'Tchami': [['deep groove house',
#    'edm',
#    'electro house',
#    'future house',
#    'house',
#    'pop dance',
#    'progressive house']],
#  'TroyBoi': [['bass trap', 'electronic trap']],
#  'Sam Feldt': [['edm', 'pop dance', 'tropical house']],
#  'Jack Ü': [['edm', 'electro house', 'pop dance']],
#  'Shoffy': [['chill pop', 'la pop']],
#  'Diplo': [['dance pop', 'edm', 'electro house', 'moombahton', 'pop dance']],
#  'Keys N Krates': [['brostep',
#    'edm',
#    'electro house',
#    'electronic trap',
#    'livetronica']],
#  'Glass Animals': [['gauze pop',
#    'indietronica',
#    'modern rock',
#    'pov: indie',
#    'shiver pop']],
#  'Jauz': [['brostep', 'edm', 'electro house']],
#  'Flosstradamus': [['brostep',
#    'edm',
#    'electro house',
#    'electronic trap',
#    'mashup']],
#  'RL Grime': [['brostep', 'edm', 'electro house', 'electronic trap']],
#  'Party Favor': [['brostep', 'edm', 'electro house', 'electronic trap']],
#  'Kungs': [['edm', 'pop dance', 'uk dance']],
#  'Steve Aoki': [['edm', 'electro house', 'pop dance']],
#  'What So Not': [['aussietronica',
#    'brostep',
#    'edm',
#    'electro house',
#    'electronic trap',
#    'escape room',
#    'vapor twitch']],
#  'Cheat Codes': [['edm', 'pop', 'pop dance']],
#  'Tiga': [['alternative dance',
#    'canadian electronic',
#    'dance-punk',
#    'electroclash',
#    'electronica',
#    'filter house',
#    'minimal techno',
#    'new rave']],
#  'Destructo': [['bass house', 'electro house']],
#  'Sevenn': [['brazilian edm']],
#  'Dillon Francis': [['brostep',
#    'edm',
#    'electro house',
#    'moombahton',
#    'pop dance',
#    'progressive electro house',
#    'slap house']],
#  'Gucci Mane': [['atl hip hop',
#    'dirty south rap',
#    'hip hop',
#    'pop rap',
#    'rap',
#    'southern hip hop',
#    'trap']],
#  'First Aid Kit': [['swedish americana', 'swedish country']],
#  'The New Basement Tapes': [['indie folk',
#    'new americana',
#    'roots rock',
#    'stomp and holler']],
#  'Shakey Graves': [['austin americana',
#    'austindie',
#    'indie folk',
#    'new americana',
#    'seattle indie',
#    'stomp and holler']],
#  'Kat Edmonson': [['contemporary vocal jazz', 'jazz pop']],
#  'Trampled by Turtles': [['duluth indie',
#    'indie folk',
#    'jam band',
#    'new americana',
#    'progressive bluegrass',
#    'stomp and holler']],
#  'Father John Misty': [['art pop',
#    'chamber pop',
#    'indie rock',
#    'singer-songwriter',
#    'stomp and holler']],
#  'Oscar Isaac': [['movie tunes']],
#  'Angus & Julia Stone': [['australian indie folk', 'indie folk']],
#  'The Decemberists': [['baroque pop',
#    'canadian indie',
#    'chamber pop',
#    'indie rock',
#    'modern folk rock',
#    'stomp and holler']],
#  'KALEO': [['icelandic indie', 'icelandic rock', 'modern alternative rock']],
#  'Tom Waits': [['folk', 'singer-songwriter']],
#  'Leon Bridges': [['modern blues', 'neo soul', 'soul']],
#  'Sturgill Simpson': [['alternative americana',
#    'kentucky roots',
#    'nashville singer-songwriter',
#    'new americana',
#    'outlaw country']],
#  'Chicano Batman': [['la indie',
#    'latinx alternative',
#    'psychedelic soul',
#    'tropical alternativo']],
#  'NEEDTOBREATHE': [['ccm',
#    'christian alternative rock',
#    'christian indie',
#    'christian music',
#    'folk-pop']],
#  'Witt Lowry': [['deep underground hip hop', 'indie pop rap']],
#  'Baaba Maal': [['afropop',
#    'desert blues',
#    'griot',
#    'mbalax',
#    'musique peule',
#    'world']],
#  'T.I.': [['atl hip hop',
#    'dirty south rap',
#    'gangster rap',
#    'hip hop',
#    'pop rap',
#    'rap',
#    'southern hip hop',
#    'trap']],
#  'Future': [[]],
#  'KYLE': [['deep underground hip hop',
#    'indie pop rap',
#    'meme rap',
#    'pop rap',
#    'viral trap']],
#  'DJ Khaled': [['hip hop', 'miami hip hop', 'pop rap', 'rap']],
#  'Playboi Carti': [['atl hip hop', 'plugg', 'pluggnb', 'rage rap', 'rap']],
#  'Luis Fonsi': [['latin pop', 'puerto rican pop']],
#  'JAY-Z': [['east coast hip hop',
#    'gangster rap',
#    'hip hop',
#    'pop rap',
#    'rap']],
#  'Young Money': [['dirty south rap',
#    'pop rap',
#    'rap',
#    'southern hip hop',
#    'trap']],
#  '3rddy Baby': [[]],
#  'Eminem': [['detroit hip hop', 'hip hop', 'rap']],
#  'A$AP Rocky': [['east coast hip hop', 'hip hop', 'rap', 'trap']],
#  'Dr. Dre': [['g funk', 'gangster rap', 'hip hop', 'rap', 'west coast rap']],
#  'Mike WiLL Made-It': [['atl hip hop', 'rap', 'southern hip hop', 'trap']],
#  'NAV': [['canadian hip hop', 'canadian trap', 'melodic rap', 'rap', 'trap']],
#  'Metro Boomin': [['hip hop', 'rap']],
#  'Cook Laflare': [['cincinnati rap']],
#  'Ty Dolla $ign': [['hip hop',
#    'pop rap',
#    'r&b',
#    'southern hip hop',
#    'trap',
#    'trap soul']],
#  'DRAM': [['pop rap',
#    'trap',
#    'underground hip hop',
#    'viral trap',
#    'virginia hip hop']],
#  'Moon Taxi': [['indie poptimism', 'modern alternative rock']],
#  'Jonas Blue': [['pop', 'pop dance', 'tropical house', 'uk dance']],
#  'Niall Horan': [['pop']],
#  'ItaloBrothers': [['hands up', 'italo dance']],
#  'Kevin Abstract': [['afrofuturism', 'lgbtq+ hip hop']],
#  'Katy Perry': [['pop']],
#  'Marc E. Bassy': [['indie pop rap', 'pop r&b']],
#  'Zedd': [['complextro', 'edm', 'german techno', 'pop', 'pop dance']],
#  'Ricegum': [['social media pop']],
#  'Jake Paul': [['social media pop']],
#  'Rachelle Maust': [[]],
#  'Maggie Lindemann': [['alt z', 'dark pop', 'pop']],
#  'The Jackson 5': [['motown', 'soul']],
#  'Jacob Sartorius': [['social media pop', 'teen pop']],
#  'Selena Gomez': [['pop', 'post-teen pop']],
#  'Taylor Swift': [['pop']],
#  'Bill Withers': [['classic soul', 'funk', 'quiet storm', 'soul']],
#  'Camila Cabello': [['dance pop', 'pop']],
#  'The Rembrandts': [['pop rock']],
#  'Will Butler': [[]],
#  'Parquet Courts': [['alternative rock',
#    'american post-punk',
#    'brooklyn indie',
#    'chamber pop',
#    'crank wave',
#    'denton tx indie',
#    'indie rock',
#    'lo-fi',
#    'neo-psychedelic',
#    'noise pop',
#    'noise rock']],
#  'Palma Violets': [['british indie rock', 'indie rock']],
#  'The Orwells': [['indie garage rock', 'indie psych-pop']],
#  'Japandroids': [['canadian indie',
#    'canadian indie rock',
#    'indie rock',
#    'modern alternative rock',
#    'modern rock',
#    'noise pop',
#    'noise rock',
#    'vancouver indie',
#    'vancouver punk']],
#  'Titus Andronicus': [['indie rock', 'lo-fi', 'new jersey indie']],
#  'Restorations': [['alternative emo',
#    'heartland rock',
#    'orgcore',
#    'philly indie']],
#  'Iron Chic': [['long island punk', 'orgcore']],
#  'Direct Hit!': [['orgcore']],
#  'Robin Schulz': [['deep euro house',
#    'deep house',
#    'edm',
#    'german dance',
#    'pop dance',
#    'tropical house']],
#  'Felix Jaehn': [['edm', 'german dance', 'pop dance', 'tropical house']],
#  'Damien Jurado': [['chamber pop', 'stomp and holler']],
#  'The Chainsmokers': [['pop']],
#  'Conrad Sewell': [['australian pop']],
#  'MOGUAI': [['dutch house',
#    'edm',
#    'electro house',
#    'german techno',
#    'pop dance',
#    'progressive electro house',
#    'progressive house']],
#  'King Topher': [[]],
#  'Sigala': [['dance pop', 'edm', 'pop dance', 'uk dance', 'uk pop']],
#  'Alex Newell': [['indie poptimism', 'strut']],
#  'Coleman Hell': [['canadian pop', 'indie poptimism']],
#  'Vance Joy': [['folk-pop', 'modern rock']],
#  'Zara Larsson': [['pop', 'scandipop', 'swedish electropop', 'swedish pop']],
#  'Kygo': [['edm', 'pop', 'pop dance', 'tropical house']],
#  'LunchMoney Lewis': [['miami hip hop']],
#  'Akon': [['dance pop']],
#  'Olly Alexander (Years & Years)': [['dance pop',
#    'gauze pop',
#    'pop',
#    'pop dance',
#    'uk pop']],
#  'One Direction': [['boy band', 'pop', 'post-teen pop', 'talent show']],
#  'Mike Posner': [['dance pop', 'pop', 'pop dance', 'pop rap']],
#  'BUNT.': [['stutter house']],
#  'NIHILS': [['austrian pop']],
#  'Royal Tongues': [['buffalo ny indie', 'indie poptimism']],
#  'Both': [['commons']],
#  'Doug Locke': [[]],
#  'Tryon': [[]],
#  'Lost Kings': [['pop dance', 'pop edm']],
#  'Parachute': [['acoustic pop',
#    'charlottesville indie',
#    'neo mellow',
#    'neon pop punk',
#    'pop rock',
#    'viral pop']],
#  'Michael Calfan': [['dutch house',
#    'edm',
#    'electro house',
#    'house',
#    'pop dance',
#    'progressive electro house',
#    'progressive house']],
#  'Otto Knows': [['dutch house',
#    'edm',
#    'electro house',
#    'pop dance',
#    'progressive electro house']],
#  'Olly Murs': [['dance pop', 'pop', 'talent show']],
#  'Madden': [['norwegian pop']],
#  'Alex Adair': [['deep tropical house',
#    'house',
#    'tropical house',
#    'uk dance']],
#  'Echosmith': [['electropop', 'indie poptimism', 'viral pop']],
#  'Floduxe': [[]],
#  'Coasts': [['hopebeat',
#    'indie anthem-folk',
#    'indie poptimism',
#    'indie surf']],
#  'Madcon': [['norwegian hip hop']],
#  'Matoma': [['pop dance', 'tropical house']],
#  'Pentatonix': [['a cappella', 'viral pop']],
#  'JR JR': [['indie poptimism', 'shimmer pop', 'stomp and holler']],
#  'Kiso': [['deep tropical house']],
#  'Deep Chills': [['tropical house']],
#  'Santa Maradona F.C.': [[]],
#  'Timeflies': [['indie pop rap']],
#  'MØ': [['dance pop', 'danish pop', 'electropop', 'pop dance']],
#  'Relient K': [['canadian ccm',
#    'christian alternative rock',
#    'christian punk',
#    'pop punk']],
#  'Coldplay': [['permanent wave', 'pop']],
#  'Zayde Wølf': [['bossbeat', 'modern alternative rock', 'rebel blues']],
#  'Fleur East': [['talent show', 'uk pop']],
#  'Birdy': [['neo mellow', 'uk pop']],
#  'Johnnyswim': [['acoustic pop', 'folk-pop']],
#  'MAGIC!': [['pop', 'reggae fusion']],
#  'NONONO': [['swedish alternative rock', 'swedish indie pop']],
#  'Nashville Cast': [[]],
#  'Band of Horses': [['chamber pop',
#    'indie folk',
#    'indie rock',
#    'indietronica',
#    'modern rock',
#    'stomp and holler']],
#  'Maddi Jane': [['viral pop']],
#  'Tom Odell': [['chill pop']],
#  'Kacey Musgraves': [['classic texas country',
#    'contemporary country',
#    'country dawn']],
#  'Donavon Frankenreiter': [[]],
#  'Sean Hayes': [[]],
#  'Joanna Wang': [['chinese audiophile',
#    'chinese jazz',
#    'mandopop',
#    'taiwan singer-songwriter']],
#  'Stevie Wonder': [['motown', 'soul']],
#  'Two Worlds': [['channel pop', 'viral pop']],
#  'Madilyn': [['viral pop']],
#  'Daniela Andrade': [['canadian contemporary r&b', 'folk-pop']],
#  'James Blunt': [['neo mellow']],
#  'Swedish House Mafia': [['edm', 'pop dance', 'progressive electro house']],
#  'Bright Eyes': [['chamber pop',
#    'indie rock',
#    'melancholia',
#    'omaha indie',
#    'stomp and holler']],
#  'Collin McLoughlin': [[]],
#  'Bill West': [[]],
#  'Norah Jones': [['contemporary vocal jazz', 'jazz pop', 'vocal jazz']],
#  'Alex Clare': [['modern alternative rock']],
#  'Walk off the Earth': [['canadian rock', 'pop rock']],
#  'José Feliciano': [['latin pop', 'puerto rican pop']],
#  'Lisa': [[]],
#  'The Fray': [['neo mellow', 'piano rock', 'pop', 'pop rock']],
#  'Jack Johnson': [['neo mellow']],
#  'Jack White': [['alternative rock',
#    'blues rock',
#    'garage rock',
#    'garage rock revival',
#    'indie rock',
#    'modern blues rock',
#    'modern rock',
#    'punk blues',
#    'rock']],
#  'Lead Belly': [['acoustic blues',
#    'blues',
#    'country blues',
#    'delta blues',
#    'texas blues',
#    'traditional blues']],
#  'The Felice Brothers': [['alternative country',
#    'chamber pop',
#    'modern folk rock',
#    'new americana',
#    'stomp and holler']],
#  'Deer Tick': [['alternative country',
#    'modern folk rock',
#    'new americana',
#    'rhode island indie',
#    'stomp and holler']],
#  'Alabama Shakes': [['alabama indie', 'modern blues rock', 'rock']],
#  'Dawes': [['indie folk',
#    'modern folk rock',
#    'new americana',
#    'stomp and holler']],
#  'Rodrigo y Gabriela': [['acoustic rock', 'world']],
#  'Lilly Lukas': [[]],
#  'The Last Internationale': [['garage rock revival']],
#  'Depeche Mode': [['dance rock',
#    'new romantic',
#    'new wave',
#    'permanent wave',
#    'rock',
#    'synthpop']],
#  'Sawyer Fredericks': [['deep talent show', 'folk-pop', 'ny roots']],
#  'Glen Hansard': [['irish rock', 'irish singer-songwriter', 'melancholia']],
#  'Chris Cornell': [['alternative metal',
#    'alternative rock',
#    'grunge',
#    'hard rock',
#    'post-grunge',
#    'rock']],
#  'Dry the River': [['melancholia']],
#  'The Silent Comedy': [['alternative americana']],
#  'William Elliott Whitmore': [['iowa indie', 'new americana']],
#  'Gary Clark Jr.': [['electric blues',
#    'modern blues rock',
#    'rock',
#    'soul blues',
#    'texas blues']],
#  'D.J. Chill': [[]],
#  'Broken Bells': [['chamber pop',
#    'indie rock',
#    'indietronica',
#    'la indie',
#    'modern rock']],
#  'Buena Vista Social Club': [['latin jazz',
#    'musica tradicional cubana',
#    'world']],
#  'Earth, Wind & Fire': [['disco', 'funk', 'jazz funk', 'soul']],
#  'Bebel Gilberto': [['bossa nova', 'downtempo']],
#  'Modest Mouse': [['alternative rock',
#    'chamber pop',
#    'indie rock',
#    'indietronica',
#    'modern rock',
#    'washington indie']],
#  'Commodores': [['adult standards',
#    'disco',
#    'funk',
#    'mellow gold',
#    'motown',
#    'quiet storm',
#    'soft rock',
#    'soul']],
#  'AtellaGali': [[]],
#  'Kool John': [['cali rap']],
#  'Guy Sebastian': [['australian pop']],
#  'Strange Talk': [['electrofox', 'metropopolis', 'shimmer pop']],
#  'Kiri T': [['chinese electropop']],
#  'Stephen': [['la pop']],
#  'Life of Dillon': [['uk pop']],
#  'Frances': [['indie anthem-folk', 'neo-singer-songwriter']],
#  'G-Eazy': [['indie pop rap', 'oakland hip hop', 'pop rap', 'rap']],
#  'Troye Sivan': [['australian pop', 'pop', 'viral pop']],
#  'Parson James': [['pop soul']],
#  'Jessie James Decker': [['contemporary country', 'country pop']],
#  'Good Charlotte': [['alternative metal',
#    'modern rock',
#    'neon pop punk',
#    'pop punk',
#    'pop rock',
#    'post-grunge']],
#  'Deorro': [['dutch house',
#    'edm',
#    'electro house',
#    'melbourne bounce',
#    'melbourne bounce international',
#    'pop dance',
#    'progressive electro house']],
#  'Kat Dahlia': [['hip pop', 'miami hip hop']],
#  'Ella Eyre': [['dance pop', 'talent show', 'uk dance', 'uk pop']],
#  'Slightly Stoopid': [['reggae fusion', 'reggae rock']],
#  'Hudson Thames': [['la pop']],
#  'Sweater Beats': [['gauze pop', 'vapor twitch']],
#  'Phoenix': [['alternative dance',
#    'indie rock',
#    'modern rock',
#    'neo-synthpop',
#    'new rave',
#    'rock independant francais',
#    'shimmer pop']],
#  'Nelly': [['dance pop',
#    'gangster rap',
#    'hip hop',
#    'pop rap',
#    'rap',
#    'st louis rap',
#    'urban contemporary']],
#  'ZHU': [['edm', 'electro house']],
#  'Flux Pavilion': [['brostep',
#    'classic dubstep',
#    'complextro',
#    'edm',
#    'electro house']],
#  'Avery Wilson': [['pop r&b']],
#  'Froogle': [['modern indie pop']],
#  'TWENTY88': [['pop r&b']],
#  'Jaymes Young': [['indie poptimism']],
#  'Empire Of The Sun': [['australian dance',
#    'australian electropop',
#    'dance rock',
#    'indietronica',
#    'neo-synthpop']],
#  'Justine Skye': [['pop r&b', 'r&b']],
#  "Scott Bradlee's Postmodern Jukebox": [['jazz cover', 'swing']],
#  'FRENSHIP': [['electropop', 'indie poptimism', 'la pop']],
#  'Yellow Claw': [['dutch house', 'edm', 'electro house', 'pop dance']],
#  'Iron & Wine': [['acoustic pop',
#    'chamber pop',
#    'indie folk',
#    'indie rock',
#    'stomp and holler']],
#  'Mr. Probz': [['pop dance']],
#  ...}

# %%
pip show pandas
# Out:
# Name: pandas
# Version: 1.4.4
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: c:\programdata\anaconda3\lib\site-packages
# Requires: numpy, python-dateutil, pytz
# Required-by: datashader, holoviews, hvplot, seaborn, statsmodels, xarray
# Note: you may need to restart the kernel to use updated packages.
